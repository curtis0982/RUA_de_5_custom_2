# %% [markdown]
# #

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0-dev20190213

# %%
print(tf.__file__ )
# Out:
# C:\Windows\system32\env002\lib\site-packages\tensorflow\__init__.py

# %% [markdown]
# # work: model  9 10

# %%
#tf.enable_eager_execution()

# %%
tf.executing_eagerly()
# Out:
# True

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import pydot_ng
import timeit
# %matplotlib inline
import datetime

# %%
import mpld3
mpld3.enable_notebook()

# %%
loss_imagepath ='images/loss/'
predict_imagepath ='images/predict/'
losspath = 'csv/loss/'
if (not (os.path.exists(losspath))):
        os.makedirs(losspath)
model_dirpath = 'h5/'
file_name='file_name'

#for func initiate
history_model='history_model'
input_tensor='input_tensor'
y_pred='y_pred'
Target_DirPath='Target_DirPath'
test_date_trim='test_date_trim'
train_date_trim='train_date_trim'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Add,Reshape,Lambda
from tensorflow.keras.optimizers import Adam, RMSprop
import tensorflow.keras.backend as K
from sklearn.metrics import r2_score
from tensorflow.keras.callbacks import EarlyStopping,CSVLogger
from tensorflow.keras.layers import LSTM
from tensorflow.keras import Input,layers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import PReLU
from tensorflow.keras.utils import plot_model
K.clear_session()
#from tcn import compiled_tcn,TCN

def adj_r2_score(r2, n, k):
    return 1-((1-r2)*((n-1)/(n-k-1)))

# %%
def plot_model_architecture(model, file_name):
    file_path = 'images/model/{}.png'.format(file_name)
    if not os.path.exists(os.path.dirname(file_path)):
        try:
            os.makedirs(os.path.dirname(file_path))
        except OSError as exc: # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise

    plot_model(model, to_file=file_path, show_shapes=True, show_layer_names=False)

# %%
X_tst_t = "X_tst_t"
X_train = "X_train"
X_test = "X_test"
test_date = "test_date"
def loadmodel(model_dirpath=model_dirpath,file_name=file_name):
    model = load_model(model_dirpath + file_name + '.h5')
    return model
def loss_image(history_model=history_model, loss_imagepath=loss_imagepath, file_name=file_name):
    import matplotlib.pyplot as plt
    loss = history_model.history['loss']
    val_loss = history_model.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.figure()
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    if (not (os.path.exists(loss_imagepath))):
                os.makedirs(loss_imagepath)
    plt.savefig(loss_imagepath +  file_name +'_loss.png')
    plt.show()    

def CSV(losspath=losspath, file_name=file_name):
    csv_logger = CSVLogger(losspath + file_name + '_log.csv')
    return csv_logger
def predict_image(history_model=history_model,X_tst_t=X_tst_t,input_tensor=input_tensor,
                  predict_imagepath=predict_imagepath, file_name=file_name):
    from sklearn.metrics import r2_score
    y_pred = model.predict([X_tst_t])
    #y_pred是三天前就知道，所以往前移三格
    y_test_pic = y_test[:]
    y_pred_pic = y_pred[delay:]
    y_test_rsquare = y_test[:]
    plt.plot(y_test_pic, label='True')
    plt.plot(y_pred_pic, label='pred')
    plt.xlabel('Observation')
    plt.ylabel('Scaled_Value')
    plt.legend()
    print("y_pred.shape:",y_pred.shape)
    print("y_test_rsquare.shape:",y_test_rsquare.shape)
    r2_test = r2_score(y_test_rsquare, y_pred)
    print('R-Squared: %f'%(r2_test))
    print("The Adjusted R2 score on the Test set is:\t{:0.3f}"\
          .format(adj_r2_score(r2_test, X_test.shape[0], X_test.shape[1])))
    if (not (os.path.exists(predict_imagepath))):
            os.makedirs(predict_imagepath)
    plt.savefig(predict_imagepath +  file_name +'_loss.png')
    plt.show()    
    return y_pred
def save_csv(y_pred=y_pred,X_train=X_train,X_test=X_test,Target_DirPath=Target_DirPath,\
             file_name=file_name,test_date=test_date):
    # 把價格縮放解除
    ## create empty table with label fields
    y_pred_data_like = np.zeros(shape=(len(y_pred), X_train.shape[1]))
    ## put the predicted values in the right field
    y_pred_data_like[:,0] = y_pred[:,0]
    ## inverse transform and then select the right field
    y_pred_data = sc.inverse_transform(y_pred_data_like)[:,0]

    #檢查測試資料的維度
    yd_size = X_test.shape[0]

    # 把價格轉換維度
    yd = y_pred_data.reshape(yd_size,)

    #把最後X天刪除(預測X天後)
    test_date_trim = np.delete(test_date, np.s_[-delay:])

    # 製作CSV
    AnalysisResult = pd.DataFrame()
    Date = pd.Series(test_date_trim)
    Close = pd.Series(yd)
    Date.name = 'Date'
    Close.name = 'Close'

    # 因為放在MC要開高低收，所以複製收盤填入
    Open = Close.copy()
    High = Close.copy()
    Low = Close.copy()
    Open.name = 'Open'
    High.name = 'High'
    Low.name = 'Low'

    AnalysisResult = pd.concat([AnalysisResult,Date], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,Close], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,Open], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,High], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,Low], axis=1)

    # 輸出CSV檔案
    import os
    Target_DirPath = 'Deep-Learning-in-Python-master/'
    if (not (os.path.exists(Target_DirPath))):
            os.makedirs(Target_DirPath)
    AnalysisResult.to_csv(Target_DirPath + file_name+'.csv', mode='w', header=True, index=False)
    
def save_train_csv(file_name=file_name):
    y_train_pred = model.predict([X_tr_t])
    # 把價格縮放解除
    ## create empty table with label fields
    y_train_pred_data_like = np.zeros(shape=(len(y_train_pred), X_train.shape[1]))
    ## put the predicted values in the right field
    y_train_pred_data_like[:,0] = y_train_pred[:,0]
    ## inverse transform and then select the right field
    y_train_pred_data = sc.inverse_transform(y_train_pred_data_like)[:,0]

    #檢查測試資料的維度
    yd_size = X_train.shape[0]

    # 把價格轉換維度
    yd = y_train_pred_data.reshape(yd_size,)

    #把最後X天刪除(預測X天後)
    train_date_trim = np.delete(train_date, np.s_[-delay:])

    # 製作CSV
    AnalysisResult = pd.DataFrame()
    Date = pd.Series(train_date_trim)
    Close = pd.Series(yd)
    Date.name = 'Date'
    Close.name = 'Close'

    # 因為放在MC要開高低收，所以複製收盤填入
    Open = Close.copy()
    High = Close.copy()
    Low = Close.copy()
    Open.name = 'Open'
    High.name = 'High'
    Low.name = 'Low'

    AnalysisResult = pd.concat([AnalysisResult,Date], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,Close], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,Open], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,High], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,Low], axis=1)

    # 輸出CSV檔案
    import os
    Target_DirPath = 'Deep-Learning-in-Python-master-train/'
    if (not (os.path.exists(Target_DirPath))):
            os.makedirs(Target_DirPath)
    AnalysisResult.to_csv(Target_DirPath + file_name+'_train.csv', mode='w', header=True, index=False)

# %% [markdown]
# # tcn

# %%
act_of_skip_connections='selu'
import tensorflow.keras.backend as K
import tensorflow.keras.layers
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Layer
from tensorflow.keras.layers import Activation, Lambda
from tensorflow.keras.layers import Conv1D, SpatialDropout1D
from tensorflow.keras.layers import Convolution1D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras import Input

from typing import List, Tuple


def channel_normalization(x):
    # type: (Layer) -> Layer
    """ Normalize a layer to the maximum activation

    This keeps a layers values between zero and one.
    It helps with relu's unbounded activation

    Args:
        x: The layer to normalize

    Returns:
        A maximal normalized layer
    """
    max_values = K.max(K.abs(x), 2, keepdims=True) + 1e-5
    out = x / max_values
    return out


def wave_net_activation(x):
    # type: (Layer) -> Layer
    """This method defines the activation used for WaveNet

    described in https://deepmind.com/blog/wavenet-generative-model-raw-audio/

    Args:
        x: The layer we want to apply the activation to

    Returns:
        A new layer with the wavenet activation applied
    """
    tanh_out = Activation('tanh')(x)
    sigm_out = Activation('sigmoid')(x)
    return tensorflow.keras.layers.multiply([tanh_out, sigm_out])


def residual_block(x, s, i, activation, nb_filters, kernel_size, padding, dropout_rate=0, name=''):
    # type: (Layer, int, int, str, int, int, str, float, str) -> Tuple[Layer, Layer]
    """Defines the residual block for the WaveNet TCN

    Args:
        x: The previous layer in the model
        s: The stack index i.e. which stack in the overall TCN
        i: The dilation power of 2 we are using for this residual block
        activation: The name of the type of activation to use
        nb_filters: The number of convolutional filters to use in this block
        kernel_size: The size of the convolutional kernel
        padding: The padding used in the convolutional layers, 'same' or 'causal'.
        dropout_rate: Float between 0 and 1. Fraction of the input units to drop.
        name: Name of the model. Useful when having multiple TCN.

    Returns:
        A tuple where the first element is the residual model layer, and the second
        is the skip connection.
    """

    original_x = x
    conv = Conv1D(filters=nb_filters, kernel_size=kernel_size,
                  dilation_rate=i, padding=padding,
                  name=name + '_d_%s_conv_%d_tanh_s%d' % (padding, i, s))(x)
    if activation == 'norm_relu':
        x = Activation('relu')(conv)
        x = Lambda(channel_normalization)(x)
    elif activation == 'wavenet':
        x = wave_net_activation(conv)
    else:
        x = Activation(activation)(conv)

    x = SpatialDropout1D(dropout_rate, name=name + '_spatial_dropout1d_%d_s%d_%f' % (i, s, dropout_rate))(x)

    # 1x1 conv.
    x = Convolution1D(nb_filters, 1, padding='same')(x)
    res_x = tensorflow.keras.layers.add([original_x, x])
    return res_x, x


def process_dilations(dilations):
    def is_power_of_two(num):
        return num != 0 and ((num & (num - 1)) == 0)

    if all([is_power_of_two(i) for i in dilations]):
        return dilations

    else:
        new_dilations = [2 ** i for i in dilations]
        # print(f'Updated dilations from {dilations} to {new_dilations} because of backwards compatibility.')
        return new_dilations


class TCN:
    """Creates a TCN layer.

        Input shape:
            A tensor of shape (batch_size, timesteps, input_dim).

        Args:
            nb_filters: The number of filters to use in the convolutional layers.
            kernel_size: The size of the kernel to use in each convolutional layer.
            dilations: The list of the dilations. Example is: [1, 2, 4, 8, 16, 32, 64].
            nb_stacks : The number of stacks of residual blocks to use.
            activation: The activations to use (norm_relu, wavenet, relu...).
            padding: The padding to use in the convolutional layers, 'causal' or 'same'.
            use_skip_connections: Boolean. If we want to add skip connections from input to each residual block.
            return_sequences: Boolean. Whether to return the last output in the output sequence, or the full sequence.
            dropout_rate: Float between 0 and 1. Fraction of the input units to drop.
            name: Name of the model. Useful when having multiple TCN.

        Returns:
            A TCN layer.
        """

    def __init__(self,
                 nb_filters=64,
                 kernel_size=2,
                 nb_stacks=1,
                 dilations=[1, 2, 4, 8, 16],
                 activation='norm_relu',
                 padding='causal',
                 use_skip_connections=True,
                 dropout_rate=0.0,
                 return_sequences=True,
                 name='tcn'):
        self.name = name
        self.return_sequences = return_sequences
        self.dropout_rate = dropout_rate
        self.use_skip_connections = use_skip_connections
        self.activation = activation
        self.dilations = dilations
        self.nb_stacks = nb_stacks
        self.kernel_size = kernel_size
        self.nb_filters = nb_filters
        self.padding = padding

        if padding != 'causal' and padding != 'same':
            raise ValueError("Only 'causal' or 'same' padding are compatible for this layer.")

        if not isinstance(nb_filters, int):
            print('An interface change occurred after the version 2.1.2.')
            print('Before: tcn.TCN(i, return_sequences=False, ...)')
            print('Now should be: tcn.TCN(return_sequences=False, ...)(i)')
            print('Second solution is to pip install keras-tcn==2.1.2 to downgrade.')
            raise Exception()

    def __call__(self, inputs, Activation_of_skip_connections='selu'):
        x = inputs
        x = Convolution1D(self.nb_filters, 1, padding=self.padding, name=self.name + '_initial_conv')(x)
        skip_connections = []
        for s in range(self.nb_stacks):
            for i in self.dilations:
                x, skip_out = residual_block(x, s, i, self.activation, self.nb_filters,
                                             self.kernel_size, self.padding, self.dropout_rate, name=self.name)
                skip_connections.append(skip_out)
        if self.use_skip_connections:
            x = tensorflow.keras.layers.add(skip_connections)
        x = Activation(Activation_of_skip_connections)(x)

        if not self.return_sequences:
            output_slice_index = -1
            x = Lambda(lambda tt: tt[:, output_slice_index, :])(x)
        return x


def compiled_tcn(num_feat,  # type: int
                 num_classes,  # type: int
                 nb_filters,  # type: int
                 kernel_size,  # type: int
                 dilations,  # type: List[int]
                 nb_stacks,  # type: int
                 max_len,  # type: int
                 activation='norm_relu',  # type: str
                 padding='causal',  # type: str
                 use_skip_connections=True,  # type: bool
                 return_sequences=True,
                 regression=False,  # type: bool
                 dropout_rate=0.05,  # type: float
                 name='tcn'  # type: str
                 ):
    # type: (...) -> tensorflow.keras.Model
    """Creates a compiled TCN model for a given task (i.e. regression or classification).

    Args:
        num_feat: The number of features of your input, i.e. the last dimension of: (batch_size, timesteps, input_dim).
        num_classes: The size of the final dense layer, how many classes we are predicting.
        nb_filters: The number of filters to use in the convolutional layers.
        kernel_size: The size of the kernel to use in each convolutional layer.
        dilations: The list of the dilations. Example is: [1, 2, 4, 8, 16, 32, 64].
        nb_stacks : The number of stacks of residual blocks to use.
        max_len: The maximum sequence length, use None if the sequence length is dynamic.
        activation: The activations to use.
        padding: The padding to use in the convolutional layers.
        use_skip_connections: Boolean. If we want to add skip connections from input to each residual block.
        return_sequences: Boolean. Whether to return the last output in the output sequence, or the full sequence.
        regression: Whether the output should be continuous or discrete.
        dropout_rate: Float between 0 and 1. Fraction of the input units to drop.
        name: Name of the model. Useful when having multiple TCN.

    Returns:
        A compiled keras TCN.
    """

    dilations = process_dilations(dilations)

    input_layer = Input(shape=(max_len, num_feat))

    x = TCN(nb_filters, kernel_size, nb_stacks, dilations, activation,
            padding, use_skip_connections, dropout_rate, return_sequences, name)(input_layer)

    print('x.shape=', x.shape)

    if not regression:
        # classification
        x = Dense(num_classes)(x)
        x = Activation('softmax')(x)
        output_layer = x
        print(f'model.x = {input_layer.shape}')
        print(f'model.y = {output_layer.shape}')
        model = Model(input_layer, output_layer)

        # https://github.com/keras-team/keras/pull/11373
        # It's now in Keras@master but still not available with pip.
        # TODO To remove later.
        def accuracy(y_true, y_pred):
            # reshape in case it's in shape (num_samples, 1) instead of (num_samples,)
            if K.ndim(y_true) == K.ndim(y_pred):
                y_true = K.squeeze(y_true, -1)
            # convert dense predictions to labels
            y_pred_labels = K.argmax(y_pred, axis=-1)
            y_pred_labels = K.cast(y_pred_labels, K.floatx())
            return K.cast(K.equal(y_true, y_pred_labels), K.floatx())

        adam = optimizers.Adam(lr=0.002, clipnorm=1.)
        model.compile(adam, loss='sparse_categorical_crossentropy', metrics=[accuracy])
        print('Adam with norm clipping.')
    else:
        # regression
        x = Dense(1)(x)
        x = Activation('linear')(x)
        output_layer = x
        print(f'model.x = {input_layer.shape}')
        print(f'model.y = {output_layer.shape}')
        model = Model(input_layer, output_layer)
        adam = optimizers.Adam(lr=0.002, clipnorm=1.)
        model.compile(adam, loss=tf_stock_loss_9)

    return model

# %% [markdown]
# # loss func

# %%
def custom_r2_score(file_name):
    Target_DirPath = 'Deep-Learning-in-Python-master/'
    file_end_with = '.csv'
    #above need to be adjust
    df_for_eval= pd.read_csv(Target_DirPath + file_name + file_end_with)
    df_for_eval['Date'] = pd.to_datetime(df_for_eval["Date"])
    df_for_eval = df_for_eval.set_index(["Date"], drop=True)

    y_pred_for_eval = df_for_eval["Close"]
    print(y_pred_for_eval.shape)
    ## create empty table with label fields
    y_pred_for_eval_data_like = np.zeros(shape=(len(y_pred_for_eval), X_train.shape[1]))
    ## put the predicted values in the right field
    y_pred_for_eval_data_like[:,0] = y_pred_for_eval[:]
    ## transform and then select the right field
    y_pred_for_eval_data = sc.transform(y_pred_for_eval_data_like)[:,0]

    r2_test = r2_score(y_test, y_pred_for_eval_data)
    print("The Adjusted R2 score on the Test set is:\t{:0.3f}"\
              .format(adj_r2_score(r2_test, X_test.shape[0], X_test.shape[1])))

    y_test_diff = np.diff(y_test) #y_test[i]與y_test[i-1]差異
    y_pred_for_eval_data_diff = np.diff(y_pred_for_eval_data)#y_pred[i]與y_pred[i-1]差異
    rsquare_product = y_test_diff*y_pred_for_eval_data_diff #兩者相乘
    def return_same_sign_bool(d):
        d = np.array(d)
        return np.where(d > 0, 1, 0)
    rsquare_product_bool = return_same_sign_bool(rsquare_product) #如果兩者相乘為正數回傳1，非正數回傳0
    print("The Custom  sign score on the Test set is:\t{:0.3f}"\
              .format((int(sum(rsquare_product_bool)) / len(rsquare_product_bool)))) 
               #計算y_test及y_pred變動同向機率
    print("The Custom  R2 score on the Test set is:\t{:0.3f}"\
              .format(adj_r2_score(r2_test, X_test.shape[0], X_test.shape[1])/2 
                      + ((int(sum(rsquare_product_bool)) / len(rsquare_product_bool)))/2 ))

# %%
data_dir = r'D:\python_code\data\us\rua'
fname = os.path.join(data_dir, 'rua_1988_2017.csv')
df = pd.read_csv(fname)
df['Date'] = pd.to_datetime(df["Date"])
df_idx = df.set_index(["Date"], drop=True)
df_idx.head(5)
# Out:
#              Close   <Open>   <High>   <Low>   <Volume>   <FastAvg>  \
# Date
# 1988-01-04  143.20   138.68   143.32  138.68          0         0.0
# 1988-01-05  144.93   143.20   146.32  143.20          0         0.0
# 1988-01-06  145.29   144.93   145.59  144.37          0         0.0
# 1988-01-07  146.35   145.29   146.39  143.99          0         0.0
# 1988-01-08  137.78   146.35   146.35  137.68          0         0.0
#
#              <SlowAvg>   <ParCl>   <RSI>   <OverBot>  ...  INDPRO      RPI  \
# Date                                                  ...
# 1988-01-04         0.0       0.0     0.0           0  ...   62.14  7252.38
# 1988-01-05         0.0       0.0     0.0           0  ...   62.14  7252.38
# 1988-01-06         0.0       0.0     0.0           0  ...   62.14  7252.38
# 1988-01-07         0.0       0.0     0.0           0  ...   62.14  7252.38
# 1988-01-08         0.0       0.0     0.0           0  ...   62.14  7252.38
#
#             PERMIT  PAYEMS    ICSA  AWHMAN  PPIACO  USSLIND  STLFSI  USREC
# Date
# 1988-01-04    1244  103758  315000    41.1   104.6     1.34     0.0      0
# 1988-01-05    1244  103758  315000    41.1   104.6     1.34     0.0      0
# 1988-01-06    1244  103758  315000    41.1   104.6     1.34     0.0      0
# 1988-01-07    1244  103758  315000    41.1   104.6     1.34     0.0      0
# 1988-01-08    1244  103758  315000    41.1   104.6     1.34     0.0      0
#
# [5 rows x 42 columns]

# %%
#把順序調換
df_idx = df_idx.sort_index(axis=0, ascending=False)
df_idx = df_idx.iloc[::-1]

data = df_idx
print(data.plot(y='Close'))
# Out:
# AxesSubplot(0.125,0.2;0.775x0.68)

# %% [markdown]
# # de10

# %%
diff = data.index.values[-1] - data.index.values[0]
days = diff.astype('timedelta64[D]')
days = days / np.timedelta64(1, 'D')
years = int(days/365)
print("total data days:",days)
print("Total data: %d years"%years)
print("80 percent data = 1988 to %d"%(1988 + int(0.8*years)))
print(diff)
delay = 10
# Out:
# total data days: 10952.0
# Total data: 30 years
# 80 percent data = 1988 to 2012
# 946252800000000000 nanoseconds

# %%
#切割訓練與測試資料
split_date = pd.Timestamp('01-01-2013')

train = data.loc[:split_date]
test = data.loc[split_date:]
test_date = test.index
test_date = pd.to_datetime(test_date)
train_date = train.index
train_date = pd.to_datetime(train_date)

# 資料正規化

from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
train_sc = sc.fit_transform(train)
test_sc = sc.transform(test)

print("train_sc.shape:",train_sc.shape)

train_sc_df = pd.DataFrame(train_sc,index=train.index,columns=train.columns)
test_sc_df = pd.DataFrame(test_sc,index=test.index,columns=test.columns)

for s in range(-delay,-delay+1):
    train_sc_df['Y_{}'.format(s)] = train_sc_df['Close'].shift(s)
    test_sc_df['Y_{}'.format(s)] = test_sc_df['Close'].shift(s)

X_train = train_sc_df.dropna().drop('Y_-'+str(delay), axis=1)
y_train = train_sc_df.dropna()['Y_-'+str(delay)]
X_train = X_train.as_matrix()
y_train = y_train.as_matrix()

X_test = test_sc_df.dropna().drop('Y_-'+str(delay), axis=1)
y_test = test_sc_df.dropna().dropna()['Y_-'+str(delay)]
X_test = X_test.as_matrix()
y_test = y_test.as_matrix()

print('Train size: (%d x %d)'%(X_train.shape[0], X_train.shape[1]))
print('Test size: (%d x %d)'%(X_test.shape[0], X_test.shape[1]))

X_tr_t = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_tst_t = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
val_split_ratio = 0.1
# Out:
# train_sc.shape: (6302, 42)
# Train size: (6292 x 42)
# Test size: (1249 x 42)
# C:\Windows\system32\env002\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:30: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:35: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
neurons=[32,128,512]
for neurons_j in neurons:
    file_name='rua_de'+str(delay)+'_tcn_n'+str(neurons_j)
    print(file_name+":")
    X_tr_t = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_tst_t = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

    input_tensor= Input(shape=(1,X_train.shape[1],))
    output = TCN(nb_filters=neurons_j, kernel_size=2, nb_stacks=1, dilations=[1, 2, 4, 8, 16], \
            activation='selu', padding='causal', use_skip_connections=True,\
            dropout_rate=0.3, return_sequences=False, name='tcn')(input_tensor)  # The TCN layers are here.

    output_tensor = Dense(1)(output)
    model = Model([input_tensor], output_tensor)
    model.compile(optimizer=Adam(lr=0.0001, clipnorm=1, clipvalue=0.5), loss='mse')
    model.summary()

    startTime = timeit.default_timer()

    history_model = model.fit(x=[X_tr_t], y=y_train, epochs=300, 
                                        batch_size=16, verbose=1,
                                        validation_split= val_split_ratio, callbacks=[CSV(losspath=losspath, file_name=file_name)],
                                        shuffle=False)
    elapsedTime = timeit.default_timer() - startTime
    print("Time taken for the Network to train : ",str(datetime.timedelta(seconds=elapsedTime)))
    plot_model_architecture(model=model, file_name=file_name)
    y_pred = predict_image(history_model=history_model,X_tst_t=X_tst_t,input_tensor=input_tensor,          
                      predict_imagepath=predict_imagepath, file_name=file_name)
    loss_image(history_model=history_model, loss_imagepath=loss_imagepath, file_name=file_name)
    save_csv(y_pred=y_pred,X_train=X_train,X_test=X_test,Target_DirPath=Target_DirPath,
                 file_name=file_name,test_date=test_date)
    save_train_csv(file_name=file_name)

    print(file_name+":")
    custom_r2_score(file_name)
# Out:
# rua_de10_tcn_n32:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1, 42)]      0
# __________________________________________________________________________________________________
# tcn_initial_conv (Conv1D)       (None, 1, 32)        1376        input_1[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_1_tanh_s0 (Co (None, 1, 32)        2080        tcn_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1, 32)        0           tcn_d_causal_conv_1_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_1_s0_0.30 (None, 1, 32)        0           activation[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 1, 32)        1056        tcn_spatial_dropout1d_1_s0_0.3000
# __________________________________________________________________________________________________
# add (Add)                       (None, 1, 32)        0           tcn_initial_conv[0][0]
#                                                                  conv1d[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_2_tanh_s0 (Co (None, 1, 32)        2080        add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 32)        0           tcn_d_causal_conv_2_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_2_s0_0.30 (None, 1, 32)        0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 1, 32)        1056        tcn_spatial_dropout1d_2_s0_0.3000
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 32)        0           add[0][0]
#                                                                  conv1d_1[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_4_tanh_s0 (Co (None, 1, 32)        2080        add_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 32)        0           tcn_d_causal_conv_4_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_4_s0_0.30 (None, 1, 32)        0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1, 32)        1056        tcn_spatial_dropout1d_4_s0_0.3000
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1, 32)        0           add_1[0][0]
#                                                                  conv1d_2[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_8_tanh_s0 (Co (None, 1, 32)        2080        add_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 32)        0           tcn_d_causal_conv_8_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_8_s0_0.30 (None, 1, 32)        0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1, 32)        1056        tcn_spatial_dropout1d_8_s0_0.3000
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1, 32)        0           add_2[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_16_tanh_s0 (C (None, 1, 32)        2080        add_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 32)        0           tcn_d_causal_conv_16_tanh_s0[0][0
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_16_s0_0.3 (None, 1, 32)        0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 1, 32)        1056        tcn_spatial_dropout1d_16_s0_0.300
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 1, 32)        0           conv1d[0][0]
#                                                                  conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
#                                                                  conv1d_3[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1, 32)        0           add_5[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 32)           0           activation_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            33          lambda[0][0]
# ==================================================================================================
# Total params: 17,089
# Trainable params: 17,089
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 5662 samples, validate on 630 samples
# Epoch 1/300
# 5662/5662==============================] - 7s 1ms/sample - loss: 1.6121 - val_loss: 0.0817
# Epoch 2/300
# 1456/5662======>.......................] - ETA: 2s - loss: 0.4533
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-ed9139ce6c0b> in <module>
#      21                                         batch_size=16, verbose=1,
#      22                                         validation_split= val_split_ratio, callbacks=[CSV(losspath=losspath, file_name=file_name)],
# ---> 23                                         shuffle=False)
#      24     elapsedTime = timeit.default_timer() - startTime
#      25     print("Time taken for the Network to train : ",str(datetime.timedelta(seconds=elapsedTime)))
#
# C:\Windows\system32\env002\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     987           validation_steps=validation_steps,
#     988           validation_freq=validation_freq,
# --> 989           steps_name='steps_per_epoch')
#     990
#     991   def evaluate(self,
#
# C:\Windows\system32\env002\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     328
#     329         # Get outputs.
# --> 330         batch_outs = f(ins_batch)
#     331         if not isinstance(batch_outs, list):
#     332           batch_outs = [batch_outs]
#
# C:\Windows\system32\env002\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3137         value = math_ops.cast(value, tensor.dtype)
#    3138       converted_inputs.append(value)
# -> 3139     outputs = self._graph_fn(*converted_inputs)
#    3140     return nest.pack_sequence_as(self._outputs_structure,
#    3141                                  [x.numpy() for x in outputs])
#
# C:\Windows\system32\env002\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#     450       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#     451           list(kwargs.keys()), list(self._arg_keywords)))
# --> 452     return self._call_flat(args)
#     453
#     454   def _filtered_call(self, args, kwargs):
#
# C:\Windows\system32\env002\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args)
#     519     # Only need to override the gradient in graph mode and when we have outputs.
#     520     if context.executing_eagerly() or not self.outputs:
# --> 521       outputs = self._inference_function.call(ctx, args)
#     522     else:
#     523       self._register_gradient()
#
# C:\Windows\system32\env002\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args)
#     307             attrs=("executor_type", executor_type,
#     308                    "config_proto", config),
# --> 309             ctx=ctx)
#     310       # Replace empty list with None
#     311       outputs = outputs or None
#
# C:\Windows\system32\env002\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      59                                                op_name, inputs, attrs,
# ---> 60                                                num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # de15

# %%
diff = data.index.values[-1] - data.index.values[0]
days = diff.astype('timedelta64[D]')
days = days / np.timedelta64(1, 'D')
years = int(days/365)
print("total data days:",days)
print("Total data: %d years"%years)
print("80 percent data = 1988 to %d"%(1988 + int(0.8*years)))
print(diff)
delay = 15
# Out:
# total data days: 13510.0
# Total data: 37 years
# 80 percent data = 1981 to 2010
# 1167264000000000000 nanoseconds

# %%
#切割訓練與測試資料
split_date = pd.Timestamp('01-01-2013')

train = data.loc[:split_date]
test = data.loc[split_date:]
test_date = test.index
test_date = pd.to_datetime(test_date)
train_date = train.index
train_date = pd.to_datetime(train_date)

# 資料正規化

from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
train_sc = sc.fit_transform(train)
test_sc = sc.transform(test)

print("train_sc.shape:",train_sc.shape)

train_sc_df = pd.DataFrame(train_sc,index=train.index,columns=train.columns)
test_sc_df = pd.DataFrame(test_sc,index=test.index,columns=test.columns)

for s in range(-delay,-delay+1):
    train_sc_df['Y_{}'.format(s)] = train_sc_df['Close'].shift(s)
    test_sc_df['Y_{}'.format(s)] = test_sc_df['Close'].shift(s)

X_train = train_sc_df.dropna().drop('Y_-'+str(delay), axis=1)
y_train = train_sc_df.dropna()['Y_-'+str(delay)]
X_train = X_train.as_matrix()
y_train = y_train.as_matrix()

X_test = test_sc_df.dropna().drop('Y_-'+str(delay), axis=1)
y_test = test_sc_df.dropna().dropna()['Y_-'+str(delay)]
X_test = X_test.as_matrix()
y_test = y_test.as_matrix()

print('Train size: (%d x %d)'%(X_train.shape[0], X_train.shape[1]))
print('Test size: (%d x %d)'%(X_test.shape[0], X_test.shape[1]))
# Out:
# train_sc.shape: (7570, 48)
# Train size: (7555 x 48)
# Test size: (1746 x 48)
# C:\Windows\system32\env002\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:30: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:35: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
neurons=[32,128,512]
for neurons_j in neurons:
    file_name='rua_de'+str(delay)+'_tcn_n'+str(neurons_j)
    print(file_name+":")
    X_tr_t = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_tst_t = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

    input_tensor= Input(shape=(1,X_train.shape[1],))
    output = TCN(nb_filters=neurons_j, kernel_size=2, nb_stacks=1, dilations=[1, 2, 4, 8, 16], \
            activation='selu', padding='causal', use_skip_connections=True,\
            dropout_rate=0.3, return_sequences=False, name='tcn')(input_tensor)  # The TCN layers are here.

    output_tensor = Dense(1)(output)
    model = Model([input_tensor], output_tensor)
    model.compile(optimizer=Adam(lr=0.0001, clipnorm=1, clipvalue=0.5), loss='mse')
    model.summary()

    startTime = timeit.default_timer()

    history_model = model.fit(x=[X_tr_t], y=y_train, epochs=300, 
                                        batch_size=16, verbose=1,
                                        validation_split= val_split_ratio, callbacks=[CSV(losspath=losspath, file_name=file_name)],
                                        shuffle=False)
    elapsedTime = timeit.default_timer() - startTime
    print("Time taken for the Network to train : ",str(datetime.timedelta(seconds=elapsedTime)))
    plot_model_architecture(model=model, file_name=file_name)
    y_pred = predict_image(history_model=history_model,X_tst_t=X_tst_t,input_tensor=input_tensor,          
                      predict_imagepath=predict_imagepath, file_name=file_name)
    loss_image(history_model=history_model, loss_imagepath=loss_imagepath, file_name=file_name)
    save_csv(y_pred=y_pred,X_train=X_train,X_test=X_test,Target_DirPath=Target_DirPath,
                 file_name=file_name,test_date=test_date)
    save_train_csv(file_name=file_name)

    print(file_name+":")
    custom_r2_score(file_name)
# Out:
# NYA_de15_tcn_n32:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 1, 48)]      0
# __________________________________________________________________________________________________
# tcn_initial_conv (Conv1D)       (None, 1, 32)        1568        input_4[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_1_tanh_s0 (Co (None, 1, 32)        2080        tcn_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 1, 32)        0           tcn_d_causal_conv_1_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_1_s0_0.30 (None, 1, 32)        0           activation_18[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 1, 32)        1056        tcn_spatial_dropout1d_1_s0_0.3000
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 1, 32)        0           tcn_initial_conv[0][0]
#                                                                  conv1d_15[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_2_tanh_s0 (Co (None, 1, 32)        2080        add_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 1, 32)        0           tcn_d_causal_conv_2_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_2_s0_0.30 (None, 1, 32)        0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 1, 32)        1056        tcn_spatial_dropout1d_2_s0_0.3000
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 1, 32)        0           add_18[0][0]
#                                                                  conv1d_16[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_4_tanh_s0 (Co (None, 1, 32)        2080        add_19[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 1, 32)        0           tcn_d_causal_conv_4_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_4_s0_0.30 (None, 1, 32)        0           activation_20[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 1, 32)        1056        tcn_spatial_dropout1d_4_s0_0.3000
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 1, 32)        0           add_19[0][0]
#                                                                  conv1d_17[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_8_tanh_s0 (Co (None, 1, 32)        2080        add_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 1, 32)        0           tcn_d_causal_conv_8_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_8_s0_0.30 (None, 1, 32)        0           activation_21[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 1, 32)        1056        tcn_spatial_dropout1d_8_s0_0.3000
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 1, 32)        0           add_20[0][0]
#                                                                  conv1d_18[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_16_tanh_s0 (C (None, 1, 32)        2080        add_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 1, 32)        0           tcn_d_causal_conv_16_tanh_s0[0][0
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_16_s0_0.3 (None, 1, 32)        0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 1, 32)        1056        tcn_spatial_dropout1d_16_s0_0.300
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 1, 32)        0           conv1d_15[0][0]
#                                                                  conv1d_16[0][0]
#                                                                  conv1d_17[0][0]
#                                                                  conv1d_18[0][0]
#                                                                  conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 1, 32)        0           add_23[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 32)           0           activation_23[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            33          lambda_3[0][0]
# ==================================================================================================
# Total params: 17,281
# Trainable params: 17,281
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 6799 samples, validate on 756 samples
# Epoch 1/300
# 6799/6799==============================] - 6s 844us/sample - loss: 1.3860 - val_loss: 0.0260
# Epoch 2/300
# 6799/6799==============================] - 4s 611us/sample - loss: 0.3146 - val_loss: 0.0405
# Epoch 3/300
# 6799/6799==============================] - 4s 610us/sample - loss: 0.1297 - val_loss: 0.0335
# Epoch 4/300
# 6799/6799==============================] - 4s 601us/sample - loss: 0.0761 - val_loss: 0.0397
# Epoch 5/300
# 6799/6799==============================] - 4s 602us/sample - loss: 0.0488 - val_loss: 0.0436
# Epoch 6/300
# 6799/6799==============================] - 4s 599us/sample - loss: 0.0356 - val_loss: 0.0400
# Epoch 7/300
# 6799/6799==============================] - 4s 604us/sample - loss: 0.0280 - val_loss: 0.0425
# Epoch 8/300
# 6799/6799==============================] - 4s 600us/sample - loss: 0.0231 - val_loss: 0.0488
# Epoch 9/300
# 6799/6799==============================] - 4s 609us/sample - loss: 0.0178 - val_loss: 0.0490
# Epoch 10/300
# 6799/6799==============================] - 4s 611us/sample - loss: 0.0146 - val_loss: 0.0448
# Epoch 11/300
# 6799/6799==============================] - 4s 603us/sample - loss: 0.0126 - val_loss: 0.0322
# Epoch 12/300
# 6799/6799==============================] - 4s 601us/sample - loss: 0.0105 - val_loss: 0.0275
# Epoch 13/300
# 6799/6799==============================] - 4s 607us/sample - loss: 2.4984e-04 - val_loss: 0.0228
# Epoch 291/300
# 6799/6799==============================] - 4s 605us/sample - loss: 2.5049e-04 - val_loss: 0.0237
# Epoch 292/300
# 6799/6799==============================] - 4s 599us/sample - loss: 2.5009e-04 - val_loss: 0.0230
# Epoch 293/300
# 6799/6799==============================] - 4s 604us/sample - loss: 2.5517e-04 - val_loss: 0.0230
# Epoch 294/300
# 6799/6799==============================] - 4s 605us/sample - loss: 2.4653e-04 - val_loss: 0.0242
# Epoch 295/300
# 6799/6799==============================] - 4s 602us/sample - loss: 2.4806e-04 - val_loss: 0.0252
# Epoch 296/300
# 6799/6799==============================] - 4s 606us/sample - loss: 2.5314e-04 - val_loss: 0.0203
# Epoch 297/300
# 6799/6799==============================] - 4s 602us/sample - loss: 2.4802e-04 - val_loss: 0.0202
# Epoch 298/300
# 6799/6799==============================] - 4s 600us/sample - loss: 2.5046e-04 - val_loss: 0.0223
# Epoch 299/300
# 6799/6799==============================] - 4s 606us/sample - loss: 2.5302e-04 - val_loss: 0.0231
# Epoch 300/300
# 6799/6799==============================] - 4s 604us/sample - loss: 2.5236e-04 - val_loss: 0.0223
# Time taken for the Network to train :  0:20:35.472755
# y_pred.shape: (1746, 1)
# y_test_rsquare.shape: (1746,)
# R-Squared: 0.302272
# The Adjusted R2 score on the Test set is:	0.283
# NYA_de15_tcn_n32:
# (1746,)
# The Adjusted R2 score on the Test set is:	0.283
# The Custom  sign score on the Test set is:	0.483
# The Custom  R2 score on the Test set is:	0.383
# NYA_de15_tcn_n128:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 1, 48)]      0
# __________________________________________________________________________________________________
# tcn_initial_conv (Conv1D)       (None, 1, 128)       6272        input_5[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_1_tanh_s0 (Co (None, 1, 128)       32896       tcn_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 1, 128)       0           tcn_d_causal_conv_1_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_1_s0_0.30 (None, 1, 128)       0           activation_24[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 1, 128)       16512       tcn_spatial_dropout1d_1_s0_0.3000
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 1, 128)       0           tcn_initial_conv[0][0]
#                                                                  conv1d_20[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_2_tanh_s0 (Co (None, 1, 128)       32896       add_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 1, 128)       0           tcn_d_causal_conv_2_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_2_s0_0.30 (None, 1, 128)       0           activation_25[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 1, 128)       16512       tcn_spatial_dropout1d_2_s0_0.3000
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 1, 128)       0           add_24[0][0]
#                                                                  conv1d_21[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_4_tanh_s0 (Co (None, 1, 128)       32896       add_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 1, 128)       0           tcn_d_causal_conv_4_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_4_s0_0.30 (None, 1, 128)       0           activation_26[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 1, 128)       16512       tcn_spatial_dropout1d_4_s0_0.3000
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 1, 128)       0           add_25[0][0]
#                                                                  conv1d_22[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_8_tanh_s0 (Co (None, 1, 128)       32896       add_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 1, 128)       0           tcn_d_causal_conv_8_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_8_s0_0.30 (None, 1, 128)       0           activation_27[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 1, 128)       16512       tcn_spatial_dropout1d_8_s0_0.3000
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 1, 128)       0           add_26[0][0]
#                                                                  conv1d_23[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_16_tanh_s0 (C (None, 1, 128)       32896       add_27[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 1, 128)       0           tcn_d_causal_conv_16_tanh_s0[0][0
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d
# Epoch 288/300
# 6799/6799==============================] - 5s 787us/sample - loss: 2.9248e-04 - val_loss: 0.0064loss:
# Epoch 289/300
# 6799/6799==============================] - 5s 790us/sample - loss: 2.8969e-04 - val_loss: 0.0064
# Epoch 290/300
# 6799/6799==============================] - 5s 792us/sample - loss: 2.7436e-04 - val_loss: 0.0053
# Epoch 291/300
# 6799/6799==============================] - 5s 789us/sample - loss: 2.7850e-04 - val_loss: 0.0061ETA: 3s - loss: 3.
# Epoch 292/300
# 6799/6799==============================] - 5s 791us/sample - loss: 2.8578e-04 - val_loss: 0.0063TA: 3s - loss: 6.965 - ETA: 2s - loss: 6.5259 - ETA: 2s - loss:  - ET - ETA: 0s - loss
# Epoch 293/300
# 6799/6799==============================] - 5s 791us/sample - loss: 2.7993e-04 - val_loss: 0.0067
# Epoch 294/300
# 6799/6799==============================] - 5s 788us/sample - loss: 2.9437e-04 - val_loss: 0.0072 ETA: 0s - los
# Epoch 295/300
# 6799/6799==============================] - 5s 785us/sample - loss: 2.8470e-04 - val_loss: 0.0063
# Epoch 296/300
# 6799/6799==============================] - 5s 793us/sample - loss: 2.8766e-04 - val_loss: 0.0051
# Epoch 297/300
# 6799/6799==============================] - 5s 786us/sample - loss: 2.9095e-04 - val_loss: 0.0079 - loss:  - ETA: 1s - l - ETA: 1s
# Epoch 298/300
# 6799/6799==============================] - 5s 791us/sample - loss: 2.7746e-04 - val_loss: 0.00572s - l
# Epoch 299/300
# 6799/6799==============================] - 5s 788us/sample - loss: 2.8012e-04 - val_loss: 0.0057
# Epoch 300/300
# 6799/6799==============================] - 5s 792us/sample - loss: 2.7722e-04 - val_loss: 0.0079
# Time taken for the Network to train :  0:26:55.575136
# y_pred.shape: (1746, 1)
# y_test_rsquare.shape: (1746,)
# R-Squared: 0.938650
# The Adjusted R2 score on the Test set is:	0.937
# NYA_de15_tcn_n512:
# (1746,)
# The Adjusted R2 score on the Test set is:	0.937
# The Custom  sign score on the Test set is:	0.493
# The Custom  R2 score on the Test set is:	0.715

# %% [markdown]
# # de20

# %%
diff = data.index.values[-1] - data.index.values[0]
days = diff.astype('timedelta64[D]')
days = days / np.timedelta64(1, 'D')
years = int(days/365)
print("total data days:",days)
print("Total data: %d years"%years)
print("80 percent data = 1988 to %d"%(1988 + int(0.8*years)))
print(diff)
delay = 20
# Out:
# total data days: 13510.0
# Total data: 37 years
# 80 percent data = 1981 to 2010
# 1167264000000000000 nanoseconds

# %%
#切割訓練與測試資料
split_date = pd.Timestamp('01-01-2013')

train = data.loc[:split_date]
test = data.loc[split_date:]
test_date = test.index
test_date = pd.to_datetime(test_date)
train_date = train.index
train_date = pd.to_datetime(train_date)

# 資料正規化

from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
train_sc = sc.fit_transform(train)
test_sc = sc.transform(test)

print("train_sc.shape:",train_sc.shape)

train_sc_df = pd.DataFrame(train_sc,index=train.index,columns=train.columns)
test_sc_df = pd.DataFrame(test_sc,index=test.index,columns=test.columns)

for s in range(-delay,-delay+1):
    train_sc_df['Y_{}'.format(s)] = train_sc_df['Close'].shift(s)
    test_sc_df['Y_{}'.format(s)] = test_sc_df['Close'].shift(s)

X_train = train_sc_df.dropna().drop('Y_-'+str(delay), axis=1)
y_train = train_sc_df.dropna()['Y_-'+str(delay)]
X_train = X_train.as_matrix()
y_train = y_train.as_matrix()

X_test = test_sc_df.dropna().drop('Y_-'+str(delay), axis=1)
y_test = test_sc_df.dropna().dropna()['Y_-'+str(delay)]
X_test = X_test.as_matrix()
y_test = y_test.as_matrix()

print('Train size: (%d x %d)'%(X_train.shape[0], X_train.shape[1]))
print('Test size: (%d x %d)'%(X_test.shape[0], X_test.shape[1]))
# Out:
# train_sc.shape: (7570, 48)
# Train size: (7550 x 48)
# Test size: (1741 x 48)
# C:\Windows\system32\env002\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:30: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:35: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
neurons=[32,128,512]
for neurons_j in neurons:
    file_name='rua_de'+str(delay)+'_tcn_n'+str(neurons_j)
    print(file_name+":")
    X_tr_t = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_tst_t = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

    input_tensor= Input(shape=(1,X_train.shape[1],))
    output = TCN(nb_filters=neurons_j, kernel_size=2, nb_stacks=1, dilations=[1, 2, 4, 8, 16], \
            activation='selu', padding='causal', use_skip_connections=True,\
            dropout_rate=0.3, return_sequences=False, name='tcn')(input_tensor)  # The TCN layers are here.

    output_tensor = Dense(1)(output)
    model = Model([input_tensor], output_tensor)
    model.compile(optimizer=Adam(lr=0.0001, clipnorm=1, clipvalue=0.5), loss='mse')
    model.summary()

    startTime = timeit.default_timer()

    history_model = model.fit(x=[X_tr_t], y=y_train, epochs=300, 
                                        batch_size=16, verbose=1,
                                        validation_split= val_split_ratio, callbacks=[CSV(losspath=losspath, file_name=file_name)],
                                        shuffle=False)
    elapsedTime = timeit.default_timer() - startTime
    print("Time taken for the Network to train : ",str(datetime.timedelta(seconds=elapsedTime)))
    plot_model_architecture(model=model, file_name=file_name)
    y_pred = predict_image(history_model=history_model,X_tst_t=X_tst_t,input_tensor=input_tensor,          
                      predict_imagepath=predict_imagepath, file_name=file_name)
    loss_image(history_model=history_model, loss_imagepath=loss_imagepath, file_name=file_name)
    save_csv(y_pred=y_pred,X_train=X_train,X_test=X_test,Target_DirPath=Target_DirPath,
                 file_name=file_name,test_date=test_date)
    save_train_csv(file_name=file_name)

    print(file_name+":")
    custom_r2_score(file_name)
# Out:
# NYA_de20_tcn_n32:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 1, 48)]      0
# __________________________________________________________________________________________________
# tcn_initial_conv (Conv1D)       (None, 1, 32)        1568        input_7[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_1_tanh_s0 (Co (None, 1, 32)        2080        tcn_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 1, 32)        0           tcn_d_causal_conv_1_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_1_s0_0.30 (None, 1, 32)        0           activation_36[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 1, 32)        1056        tcn_spatial_dropout1d_1_s0_0.3000
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 1, 32)        0           tcn_initial_conv[0][0]
#                                                                  conv1d_30[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_2_tanh_s0 (Co (None, 1, 32)        2080        add_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 1, 32)        0           tcn_d_causal_conv_2_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_2_s0_0.30 (None, 1, 32)        0           activation_37[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 1, 32)        1056        tcn_spatial_dropout1d_2_s0_0.3000
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 1, 32)        0           add_36[0][0]
#                                                                  conv1d_31[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_4_tanh_s0 (Co (None, 1, 32)        2080        add_37[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 1, 32)        0           tcn_d_causal_conv_4_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_4_s0_0.30 (None, 1, 32)        0           activation_38[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 1, 32)        1056        tcn_spatial_dropout1d_4_s0_0.3000
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 1, 32)        0           add_37[0][0]
#                                                                  conv1d_32[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_8_tanh_s0 (Co (None, 1, 32)        2080        add_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 1, 32)        0           tcn_d_causal_conv_8_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_8_s0_0.30 (None, 1, 32)        0           activation_39[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 1, 32)        1056        tcn_spatial_dropout1d_8_s0_0.3000
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 1, 32)        0           add_38[0][0]
#                                                                  conv1d_33[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_16_tanh_s0 (C (None, 1, 32)        2080        add_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 1, 32)        0           tcn_d_causal_conv_16_tanh_s0[0][0
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_16_s0_0.3 (None, 1, 32)        0           activation_40[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 1, 32)        1056        tcn_spatial_dropout1d_16_s0_0.300
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 1, 32)        0           conv1d_30[0][0]
#                                                                  conv1d_31[0][0]
#                                                                  conv1d_32[0][0]
#                                                                  conv1d_33[0][0]
#                                                                  conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 1, 32)        0           add_41[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 32)           0           activation_41[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            33          lambda_6[0][0]
# ==================================================================================================
# Total params: 17,281
# Trainable params: 17,281
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 6795 samples, validate on 755 samples
# Epoch 1/300
# 6795/6795==============================] - 6s 951us/sample - loss: 1.6100 - val_loss: 0.2215
# Epoch 2/300
# 6795/6795==============================] - 4s 621us/sample - loss: 0.3203 - val_loss: 0.2044
# Epoch 3/300
# 6795/6795==============================] - 4s 617us/sample - loss: 0.1294 - val_loss: 0.2275
# Epoch 4/300
# 6795/6795==============================] - 4s 615us/sample - loss: 0.0710 - val_loss: 0.1937
# Epoch 5/300
# 6795/6795==============================] - 4s 615us/sample - loss: 0.0473 - val_loss: 0.1360
# Epoch 6/300
# 6795/6795==============================] - 4s 615us/sample - loss: 0.0350 - val_loss: 0.1305
# Epoch 7/300
# 6795/6795==============================] - 4s 613us/sample - loss: 0.0268 - val_loss: 0.1011
# Epoch 8/300
# 6795/6795==============================] - 4s 611us/sample - loss: 0.0206 - val_loss: 0.0844
# Epoch 9/300
# 6795/6795==============================] - 4s 617us/sample - loss: 0.0166 - val_loss: 0.0544
# Epoch 10/300
# 6795/6795==============================] - 4s 617us/sample - loss: 0.0130 - val_loss: 0.0264
# Epoch 11/300
# 6795/6795==============================] - 4s 618us/sample - loss: 0.0116 - val_loss: 0.0216
# Epoch 12/300
# 6795/6795==============================] - 4s 623us/sample - loss: 0.0101 - val_loss: 0.0274
# Epoch 13/300
# 6795/6795==============================] - 4s 617us/sample - loss: 0.0084 - val_loss: 0.0237
# Epoch 14/300
# 6795/6795==============================] - 4s 619us/sample - loss: 0.0070 - val_loss: 0.0263
# Epoch 15/300
# 6795/6795==============================] - 4s 615us/sample - loss: 0.0064 - val_loss: 0.0183
# Epoch 16/300
# 6795/6795==============================] - 4s 615us/sample - loss: 0.0053 - val_loss: 0.0178
# Epoch 17/300
# 6795/6795==============================] - 4s 616us/sample - loss: 0.0050 - val_loss: 0.0173
# Epoch 18/300

# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 1, 48)]      0
# __________________________________________________________________________________________________
# tcn_initial_conv (Conv1D)       (None, 1, 128)       6272        input_8[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_1_tanh_s0 (Co (None, 1, 128)       32896       tcn_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 1, 128)       0           tcn_d_causal_conv_1_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_1_s0_0.30 (None, 1, 128)       0           activation_42[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 1, 128)       16512       tcn_spatial_dropout1d_1_s0_0.3000
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 1, 128)       0           tcn_initial_conv[0][0]
#                                                                  conv1d_35[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_2_tanh_s0 (Co (None, 1, 128)       32896       add_42[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 1, 128)       0           tcn_d_causal_conv_2_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_2_s0_0.30 (None, 1, 128)       0           activation_43[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 1, 128)       16512       tcn_spatial_dropout1d_2_s0_0.3000
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 1, 128)       0           add_42[0][0]
#                                                                  conv1d_36[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_4_tanh_s0 (Co (None, 1, 128)       32896       add_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 1, 128)       0           tcn_d_causal_conv_4_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_4_s0_0.30 (None, 1, 128)       0           activation_44[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 1, 128)       16512       tcn_spatial_dropout1d_4_s0_0.3000
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 1, 128)       0           add_43[0][0]
#                                                                  conv1d_37[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_8_tanh_s0 (Co (None, 1, 128)       32896       add_44[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 1, 128)       0           tcn_d_causal_conv_8_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_8_s0_0.30 (None, 1, 128)       0           activation_45[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 1, 128)       16512       tcn_spatial_dropout1d_8_s0_0.3000
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 1, 128)       0           add_44[0][0]
#                                                                  conv1d_38[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_16_tanh_s0 (C (None, 1, 128)       32896       add_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 1, 128)       0           tcn_d_causal_conv_16_tanh_s0[0][0
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_16_s0_0.3 (None, 1, 128)       0           activation_46[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 1, 128)       16512       tcn_spatial_dropout1d_16_s0_0.300
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 1, 128)       0           conv1d_35[0][0]
#                                                                  conv1d_36[0][0]
#                                                                  conv1d_37[0][0]
#                                                                  conv1d_38[0][0]
#                                                                  conv1d_39[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 1, 128)       0           add_47[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 128)          0           activation_47[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            129         lambda_7[0][0]
# ==================================================================================================
# Total params: 253,441
# Trainable params: 253,441
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 6795 samples, validate on 755 samples
# Epoch 1/300
# ...
# Epoch 166/300
# 6795/6795==============================] - 6s 816us/sample - loss: 4.3312e-04 - val_loss: 0.0102
# Epoch 167/300
# 6795/6795==============================] - 5s 809us/sample - loss: 4.3551e-04 - val_loss: 0.0104
# Epoch 168/300
# 6795/6795==============================] - 5s 802us/sample - loss: 4.4313e-04 - val_loss: 0.0118
# Epoch 169/300
# 6795/6795==============================] - 5s 806us/sample - loss: 4.4131e-04 - val_loss: 0.0115A: 0s - loss: 4.1426
# Epoch 170/300
# 6795/6795==============================] - 6s 810us/sample - loss: 4.4375e-04 - val_loss: 0.0098
# Epoch 171/300
# 6795/6795==============================] - 6s 810us/sample - loss: 4.3258e-04 - val_loss: 0.0106 1s - loss: - ETA: 1
# Epoch 172/300
# 6795/6795==============================] - 5s 806us/sample - loss: 4.4092e-04 - val_loss: 0.0100
# Epoch 173/300
# 6795/6795==============================] - 6s 825us/sample - loss: 4.3090e-04 - val_loss: 0.0073
# Epoch 174/300
# %%
import numpy as np
import pandas as pd
delays = [10,15,20]
neurons=[32,128,512]
for delays_i in delays
    for neurons_j in neurons:
        file_name='rua_de'+str(delays)+'_tcn_n'+str(neurons_j)
        print("=============================================")
        print(file_name)
        Target_DirPath = 'Deep-Learning-in-Python-master/'
        file_end_with = '.csv'
        #above need to be adjust
        df_for_eval= pd.read_csv(Target_DirPath + file_name + file_end_with)
        df_for_eval['Date'] = pd.to_datetime(df_for_eval["Date"])
        df_for_eval = df_for_eval.set_index(["Date"], drop=True)

        y_pred_for_eval = df_for_eval["Close"]
        ## create empty table with label fields
        y_pred_for_eval_data_like = np.zeros(shape=(len(y_pred_for_eval), X_train.shape[1]))
        ## put the predicted values in the right field
        y_pred_for_eval_data_like[:,0] = y_pred_for_eval[:]
        ## transform and then select the right field
        y_pred_for_eval_data = sc.transform(y_pred_for_eval_data_like)[:,0]


        r2_test = r2_score(y_test, y_pred_for_eval_data)
        print("The Adjusted R2 score on the Test set is:\t{:0.3f}"\
                  .format(adj_r2_score(r2_test, X_test.shape[0], X_test.shape[1])))

        y_test_diff = np.diff(y_test) #y_test[i]與y_test[i-1]差異
        y_pred_for_eval_data_diff = np.diff(y_pred_for_eval_data)#y_pred[i]與y_pred[i-1]差異
        rsquare_product = y_test_diff*y_pred_for_eval_data_diff #兩者相乘
        def return_same_sign_bool(d):
            d = np.array(d)
            return np.where(d > 0, 1, 0)
        rsquare_product_bool = return_same_sign_bool(rsquare_product) #如果兩者相乘為正數回傳1，非正數回傳0
        print("The Custom  sign score on the Test set is:\t{:0.3f}"\
                  .format((int(sum(rsquare_product_bool)) / len(rsquare_product_bool)))) 
                   #計算y_test及y_pred變動同向機率

        #Custom  sign score_2
        y_test_after = np.roll(y_test,-delay) #y_test[i]與y_test[i-1]差異
        y_pred_for_eval_data_after = np.roll(y_pred_for_eval_data,-delay)#y_pred[i]與y_pred[i-1]差異
        y_test__cl = np.subtract(y_test_after,y_test)
        y_pred_for_eval_data_cl = np.subtract(y_pred_for_eval_data_after,y_pred_for_eval_data)

        sign_raw = np.multiply(y_test__cl, y_pred_for_eval_data_cl)

        sign_bool_func = np.vectorize(lambda elements : 1 if elements <= 0  else 0)
        sign_bool = sign_bool_func(sign_raw)
        sign_bool[np.r_[-delay:-1]] = 0

        print("The Custom  sign score_2 on the Test set is:\t{:0.3f}"\
                  .format((int(sum(sign_bool)) / (len(sign_bool)-delay)))) 
                   #計算y_test及y_pred變動同向機率
# Out:
#   File "<ipython-input-28-ab6e654e2bbe>", line 5
#     for delays_i in delays
#                           ^
# SyntaxError: invalid syntax

# %%
indices = tf.constant([[[0,0],[0,1]]])
updates = tf.constant([[[5, 5, 5, 5],[5, 5, 5, 5]]])
shape = tf.constant([4, 4, 4])
scatter = tf.scatter_nd(indices, updates, shape)
print(scatter)

# %%
indices = tf.constant([[[0,0],[0,1]]])
updates = tf.constant([[5, 5]])
shape = tf.constant([3, 5])
scatter = tf.scatter_nd(indices, updates, shape)
print(scatter)

# %%
de = list()
de = [0,2,6,7,8,9]
de[-1]
