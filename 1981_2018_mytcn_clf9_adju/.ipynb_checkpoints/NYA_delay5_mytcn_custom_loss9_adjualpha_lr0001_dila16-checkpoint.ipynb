# %% [markdown]
# #

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0-dev20190213

# %%
print(tf.__file__ )
# Out:
# C:\Windows\system32\env002\lib\site-packages\tensorflow\__init__.py

# %% [markdown]
# # work: model  9 10

# %%
#tf.enable_eager_execution()

# %%
tf.executing_eagerly()
# Out:
# True

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import pydot_ng
# %matplotlib inline

# %%
import mpld3
mpld3.enable_notebook()

# %%
data_dir = r'D:\python_code\data\stock\^NYA'
fname = os.path.join(data_dir, 'NYA 1981 2018 technical_custom_loss4.csv')
df = pd.read_csv(fname)
df['Date'] = pd.to_datetime(df["Date"])
df_idx = df.set_index(["Date"], drop=True)
df_idx.head(5)
# Out:
#              Close  vex_sign  cave_sign   <Open>   <High>   <Low>   <Volume>  \
# Date
# 1981-01-02  827.50         0          0   827.50   827.50  827.50          0
# 1981-01-05  836.17         0          1   836.17   836.17  836.17          0
# 1981-01-06  836.81         0          1   836.81   836.81  836.81          0
# 1981-01-07  817.24         1          0   817.24   817.24  817.24          0
# 1981-01-08  805.72         1          0   805.72   805.72  805.72          0
#
#              <ParCl>   <FastAvg>   <SlowAvg>  ...   INDPRO       RPI  PERMIT  \
# Date                                          ...
# 1981-01-02       0.0         0.0         0.0  ...  52.4688  5723.536    1221
# 1981-01-05       0.0         0.0         0.0  ...  52.4688  5723.536    1221
# 1981-01-06       0.0         0.0         0.0  ...  52.4688  5723.536    1221
# 1981-01-07       0.0         0.0         0.0  ...  52.4688  5723.536    1221
# 1981-01-08       0.0         0.0         0.0  ...  52.4688  5723.536    1221
#
#             PAYEMS    ICSA  AWHMAN  PPIACO  USSLIND  STLFSI  USREC
# Date
# 1981-01-02   91037  399000    40.1    95.2      0.0     0.0      0
# 1981-01-05   91037  410000    40.1    95.2      0.0     0.0      0
# 1981-01-06   91037  410000    40.1    95.2      0.0     0.0      0
# 1981-01-07   91037  410000    40.1    95.2      0.0     0.0      0
# 1981-01-08   91037  410000    40.1    95.2      0.0     0.0      0
#
# [5 rows x 48 columns]

# %%
#把順序調換
df_idx = df_idx.sort_index(axis=0, ascending=False)
df_idx = df_idx.iloc[::-1]

# %%
df_idx.head(5)
# Out:
#              Close  vex_sign  cave_sign   <Open>   <High>   <Low>   <Volume>  \
# Date
# 1981-01-02  827.50         0          0   827.50   827.50  827.50          0
# 1981-01-05  836.17         0          1   836.17   836.17  836.17          0
# 1981-01-06  836.81         0          1   836.81   836.81  836.81          0
# 1981-01-07  817.24         1          0   817.24   817.24  817.24          0
# 1981-01-08  805.72         1          0   805.72   805.72  805.72          0
#
#              <ParCl>   <FastAvg>   <SlowAvg>  ...   INDPRO       RPI  PERMIT  \
# Date                                          ...
# 1981-01-02       0.0         0.0         0.0  ...  52.4688  5723.536    1221
# 1981-01-05       0.0         0.0         0.0  ...  52.4688  5723.536    1221
# 1981-01-06       0.0         0.0         0.0  ...  52.4688  5723.536    1221
# 1981-01-07       0.0         0.0         0.0  ...  52.4688  5723.536    1221
# 1981-01-08       0.0         0.0         0.0  ...  52.4688  5723.536    1221
#
#             PAYEMS    ICSA  AWHMAN  PPIACO  USSLIND  STLFSI  USREC
# Date
# 1981-01-02   91037  399000    40.1    95.2      0.0     0.0      0
# 1981-01-05   91037  410000    40.1    95.2      0.0     0.0      0
# 1981-01-06   91037  410000    40.1    95.2      0.0     0.0      0
# 1981-01-07   91037  410000    40.1    95.2      0.0     0.0      0
# 1981-01-08   91037  410000    40.1    95.2      0.0     0.0      0
#
# [5 rows x 48 columns]

# %%
data = df_idx
data.plot(y='Close')

# %%
diff = data.index.values[-1] - data.index.values[0]
days = diff.astype('timedelta64[D]')
days = days / np.timedelta64(1, 'D')
years = int(days/365)
print("total data days:",days)
print("Total data: %d years"%years)
print("80 percent data = 1981 to %d"%(1981 + int(0.8*years)))
print(diff)
# Out:
# total data days: 13510.0
# Total data: 37 years
# 80 percent data = 1981 to 2010
# 1167264000000000000 nanoseconds

# %%
#切割訓練與測試資料
split_date = pd.Timestamp('01-01-2011')

train = data.loc[:split_date]
test = data.loc[split_date:]
test_date = test.index
test_date = pd.to_datetime(test_date)
train_date = train.index
train_date = pd.to_datetime(train_date)

# %%
# 資料正規化

from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
train_sc = sc.fit_transform(train)
test_sc = sc.transform(test)
# Out:
# C:\Windows\system32\env002\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
#without sc
#train_sc = train
#test_sc = test

# %%
train_sc.shape
# Out:
# (7570, 48)

# %%
train_sc_df = pd.DataFrame(train_sc,index=train.index,columns=train.columns)
test_sc_df = pd.DataFrame(test_sc,index=test.index,columns=test.columns)

# %%
train_sc_df
# Out:
#                Close  vex_sign  cave_sign    <Open>    <High>     <Low>  \
# Date
# 1981-01-02  0.021235       0.0        0.0  0.021235  0.021070  0.021381
# 1981-01-05  0.022129       0.0        1.0  0.022129  0.021958  0.022282
# 1981-01-06  0.022195       0.0        1.0  0.022195  0.022024  0.022348
# 1981-01-07  0.020176       1.0        0.0  0.020176  0.020020  0.020315
# 1981-01-08  0.018987       1.0        0.0  0.018987  0.018840  0.019118
# 1981-01-09  0.019249       0.0        1.0  0.019249  0.019100  0.019382
# 1981-01-12  0.019336       0.0        1.0  0.019336  0.019186  0.019469
# 1981-01-13  0.019150       1.0        0.0  0.019150  0.019002  0.019282
# 1981-01-14  0.019369       0.0        1.0  0.019369  0.019219  0.019502
# 1981-01-15  0.019849       0.0        1.0  0.019849  0.019695  0.019985
# 1981-01-16  0.020220       0.0        1.0  0.020220  0.020064  0.020360
# 1981-01-19  0.019968       1.0        0.0  0.019968  0.019814  0.020106
# 1981-01-20  0.018343       1.0        0.0  0.018343  0.018201  0.018469
# 1981-01-21  0.018102       1.0        0.0  0.018103  0.017962  0.018227
# 1981-01-22  0.017415       1.0        0.0  0.017415  0.017280  0.017535
# 1981-01-23  0.017372       1.0        0.0  0.017372  0.017237  0.017492
# 1981-01-26  0.017077       1.0        0.0  0.017077  0.016944  0.017194
# 1981-01-27  0.017885       0.0        1.0  0.017885  0.017746  0.018008
# 1981-01-28  0.017437       1.0        0.0  0.017437  0.017302  0.017557
# 1981-01-29  0.017339       1.0        0.0  0.017339  0.017205  0.017458
# 1981-01-30  0.016881       1.0        0.0  0.016881  0.016750  0.016997
# 2017-12-14 -0.130901    0.0  1.256825
# 2017-12-15 -0.128222    0.0  1.256539
# 2017-12-18 -0.128222    0.0  1.257722
# 2017-12-19 -0.128222    0.0  1.259073
# 2017-12-20 -0.128222    0.0  1.262282
# 2017-12-21 -0.128222    0.0  1.257716
# 2017-12-22 -0.117509    0.0       NaN
# 2017-12-26 -0.117509    0.0       NaN
# 2017-12-27 -0.117509    0.0       NaN
# 2017-12-28 -0.117509    0.0       NaN
# 2017-12-29 -0.121527    0.0       NaN
#
# [1761 rows x 49 columns]

# %%
#X_train = train_sc_df.dropna().drop('Y', axis=1)
X_train = train_sc_df.dropna().drop('Y_-5', axis=1)
y_train = train_sc_df.dropna()['Y_-5']
X_train = X_train.as_matrix()
y_train = y_train.as_matrix()
# Out:
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """

# %%
X_train
# Out:
# array([[0.02123455, 0.        , 0.        , ..., 0.44481605, 0.1198527 ,
#         0.        ],
#        [0.0221293 , 0.        , 1.        , ..., 0.44481605, 0.1198527 ,
#         0.        ],
#        [0.02219534, 0.        , 1.        , ..., 0.44481605, 0.1198527 ,
#         0.        ],
#        ...,
#        [0.75175002, 0.        , 1.        , ..., 0.68896321, 0.03615668,
#         0.        ],
#        [0.75439815, 0.        , 1.        , ..., 0.68896321, 0.03615668,
#         0.        ],
#        [0.75373767, 1.        , 0.        , ..., 0.68896321, 0.03615668,
#         0.        ]])

# %%
X_train.shape
# Out:
# (7565, 48)

# %%
y_train.shape
# Out:
# (7565,)

# %%
X_test = test_sc_df.dropna().drop('Y_-5', axis=1)
y_test = test_sc_df.dropna().dropna()['Y_-5']
X_test = X_test.as_matrix()
y_test = y_test.as_matrix()
# Out:
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Windows\system32\env002\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %%
y_train
# Out:
# array([0.01924897, 0.01933566, 0.0191499 , ..., 0.75746527, 0.75647764,
#        0.7577274 ])

# %%
X_test
# Out:
# array([[ 0.76597828,  0.        ,  1.        , ...,  0.67892977,
#          0.02360228,  0.        ],
#        [ 0.76372954,  1.        ,  0.        , ...,  0.67892977,
#          0.02360228,  0.        ],
#        [ 0.76557271,  0.        ,  1.        , ...,  0.67892977,
#          0.02360228,  0.        ],
#        ...,
#        [ 1.25138934,  1.        ,  0.        , ...,  0.68060201,
#         -0.1282223 ,  0.        ],
#        [ 1.25139037,  0.        ,  1.        , ...,  0.68060201,
#         -0.1282223 ,  0.        ],
#        [ 1.25682491,  0.        ,  1.        , ...,  0.68060201,
#         -0.1282223 ,  0.        ]])

# %%
y_test
# Out:
# array([0.75794103, 0.76336834, 0.77413216, ..., 1.25907262, 1.26228216,
#        1.25771553])

# %%
print('Train size: (%d x %d)'%(X_train.shape[0], X_train.shape[1]))
print('Test size: (%d x %d)'%(X_test.shape[0], X_test.shape[1]))
# Out:
# Train size: (7565 x 48)
# Test size: (1756 x 48)

# %% [markdown]
# # setup

# %%
loss_imagepath ='images/loss/'
predict_imagepath ='images/predict/'
losspath = 'csv/loss/'
if (not (os.path.exists(losspath))):
        os.makedirs(losspath)
model_dirpath = 'h5/'
file_name='file_name'

#for func initiate
history_model='history_model'
input_tensor='input_tensor'
y_pred='y_pred'
Target_DirPath='Target_DirPath'
test_date_trim='test_date_trim'
train_date_trim='train_date_trim'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Add,Reshape,Lambda
from tensorflow.keras.optimizers import Adam, RMSprop
import tensorflow.keras.backend as K
from sklearn.metrics import r2_score
from tensorflow.keras.callbacks import EarlyStopping,CSVLogger
from tensorflow.keras.layers import LSTM
from tensorflow.keras import Input,layers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import PReLU
from tensorflow.keras.utils import plot_model
K.clear_session()
#from tcn import compiled_tcn,TCN

def adj_r2_score(r2, n, k):
    return 1-((1-r2)*((n-1)/(n-k-1)))

X_tr_t = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_tst_t = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])


val_split_ratio = 0.1
penalty=0.1

# %%
def plot_model_architecture(model, file_name):
    file_path = 'images/model/{}.png'.format(file_name)
    if not os.path.exists(os.path.dirname(file_path)):
        try:
            os.makedirs(os.path.dirname(file_path))
        except OSError as exc: # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise

    plot_model(model, to_file=file_path, show_shapes=True)

# %%
def loadmodel(model_dirpath=model_dirpath,file_name=file_name):
    model = load_model(model_dirpath + file_name + '.h5')
    return model
def loss_image(history_model=history_model, loss_imagepath=loss_imagepath, file_name=file_name):
    import matplotlib.pyplot as plt
    print(history_model.history.keys())
    loss = history_model.history['loss']
    val_loss = history_model.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.figure()
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    if (not (os.path.exists(loss_imagepath))):
                os.makedirs(loss_imagepath)
    plt.savefig(loss_imagepath +  file_name +'_lr0001_dila16_loss.png')
def CSV(losspath=losspath, file_name=file_name):
    csv_logger = CSVLogger(losspath + file_name + '_lr0001_dila16_log.csv')
    return csv_logger
def predict_image(history_model=history_model,X_tst_t=X_tst_t,input_tensor=input_tensor,
                  
                  predict_imagepath=predict_imagepath, file_name=file_name):
    from sklearn.metrics import r2_score
    y_pred = model.predict([X_tst_t])
    #y_pred是三天前就知道，所以往前移三格
    y_test_pic = y_test[:]
    y_pred_pic = y_pred[5:]
    y_test_rsquare = y_test[:]
    plt.plot(y_test_pic, label='True')
    plt.plot(y_pred_pic, label='pred')
    plt.xlabel('Observation')
    plt.ylabel('Scaled_Value')
    plt.legend()
    print("y_pred.shape:",y_pred.shape)
    print("y_test_rsquare.shape:",y_test_rsquare.shape)
    r2_test = r2_score(y_test_rsquare, y_pred)
    print('R-Squared: %f'%(r2_test))
    print("The Adjusted R2 score on the Test set is:\t{:0.3f}"\
          .format(adj_r2_score(r2_test, X_test.shape[0], X_test.shape[1])))
    if (not (os.path.exists(predict_imagepath))):
            os.makedirs(predict_imagepath)
    plt.savefig(predict_imagepath +  file_name +'_lr0001_dila16_loss.png')
    plt.show()    
    return y_pred
def save_csv(y_pred=y_pred,X_train=X_train,X_test=X_test,Target_DirPath=Target_DirPath,\
             file_name=file_name,test_date=test_date):
    # 把價格縮放解除
    ## create empty table with label fields
    y_pred_data_like = np.zeros(shape=(len(y_pred), X_train.shape[1]))
    ## put the predicted values in the right field
    y_pred_data_like[:,0] = y_pred[:,0]
    ## inverse transform and then select the right field
    y_pred_data = sc.inverse_transform(y_pred_data_like)[:,0]

    #檢查測試資料的維度
    yd_size = X_test.shape[0]

    # 把價格轉換維度
    yd = y_pred_data.reshape(yd_size,)

    #把最後X天刪除(預測X天後)
    test_date_trim = np.delete(test_date, np.s_[-5:])

    # 製作CSV
    AnalysisResult = pd.DataFrame()
    Date = pd.Series(test_date_trim)
    Close = pd.Series(yd)
    Date.name = 'Date'
    Close.name = 'Close'

    # 因為放在MC要開高低收，所以複製收盤填入
    Open = Close.copy()
    High = Close.copy()
    Low = Close.copy()
    Open.name = 'Open'
    High.name = 'High'
    Low.name = 'Low'

    AnalysisResult = pd.concat([AnalysisResult,Date], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,Close], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,Open], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,High], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,Low], axis=1)

    # 輸出CSV檔案
    import os
    Target_DirPath = 'Deep-Learning-in-Python-master/'
    if (not (os.path.exists(Target_DirPath))):
            os.makedirs(Target_DirPath)
    AnalysisResult.to_csv(Target_DirPath + file_name+'_lr0001_dila16.csv', mode='w', header=True, index=False)
    
def save_train_csv(file_name=file_name):
    y_train_pred = model.predict([X_tr_t])
    # 把價格縮放解除
    ## create empty table with label fields
    y_train_pred_data_like = np.zeros(shape=(len(y_train_pred), X_train.shape[1]))
    ## put the predicted values in the right field
    y_train_pred_data_like[:,0] = y_train_pred[:,0]
    ## inverse transform and then select the right field
    y_train_pred_data = sc.inverse_transform(y_train_pred_data_like)[:,0]

    #檢查測試資料的維度
    yd_size = X_train.shape[0]

    # 把價格轉換維度
    yd = y_train_pred_data.reshape(yd_size,)

    #把最後X天刪除(預測X天後)
    train_date_trim = np.delete(train_date, np.s_[-5:])

    # 製作CSV
    AnalysisResult = pd.DataFrame()
    Date = pd.Series(train_date_trim)
    Close = pd.Series(yd)
    Date.name = 'Date'
    Close.name = 'Close'

    # 因為放在MC要開高低收，所以複製收盤填入
    Open = Close.copy()
    High = Close.copy()
    Low = Close.copy()
    Open.name = 'Open'
    High.name = 'High'
    Low.name = 'Low'

    AnalysisResult = pd.concat([AnalysisResult,Date], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,Close], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,Open], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,High], axis=1)
    AnalysisResult = pd.concat([AnalysisResult,Low], axis=1)

    # 輸出CSV檔案
    import os
    Target_DirPath = 'Deep-Learning-in-Python-master-train/'
    if (not (os.path.exists(Target_DirPath))):
            os.makedirs(Target_DirPath)
    AnalysisResult.to_csv(Target_DirPath + file_name+'_lr0001_dila16_train.csv', mode='w', header=True, index=False)

# %% [markdown]
# # tcn

# %%
act_of_skip_connections='selu'

# %%
import tensorflow.keras.backend as K
import tensorflow.keras.layers
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Layer
from tensorflow.keras.layers import Activation, Lambda
from tensorflow.keras.layers import Conv1D, SpatialDropout1D
from tensorflow.keras.layers import Convolution1D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras import Input

from typing import List, Tuple


def channel_normalization(x):
    # type: (Layer) -> Layer
    """ Normalize a layer to the maximum activation

    This keeps a layers values between zero and one.
    It helps with relu's unbounded activation

    Args:
        x: The layer to normalize

    Returns:
        A maximal normalized layer
    """
    max_values = K.max(K.abs(x), 2, keepdims=True) + 1e-5
    out = x / max_values
    return out


def wave_net_activation(x):
    # type: (Layer) -> Layer
    """This method defines the activation used for WaveNet

    described in https://deepmind.com/blog/wavenet-generative-model-raw-audio/

    Args:
        x: The layer we want to apply the activation to

    Returns:
        A new layer with the wavenet activation applied
    """
    tanh_out = Activation('tanh')(x)
    sigm_out = Activation('sigmoid')(x)
    return tensorflow.keras.layers.multiply([tanh_out, sigm_out])


def residual_block(x, s, i, activation, nb_filters, kernel_size, padding, dropout_rate=0, name=''):
    # type: (Layer, int, int, str, int, int, str, float, str) -> Tuple[Layer, Layer]
    """Defines the residual block for the WaveNet TCN

    Args:
        x: The previous layer in the model
        s: The stack index i.e. which stack in the overall TCN
        i: The dilation power of 2 we are using for this residual block
        activation: The name of the type of activation to use
        nb_filters: The number of convolutional filters to use in this block
        kernel_size: The size of the convolutional kernel
        padding: The padding used in the convolutional layers, 'same' or 'causal'.
        dropout_rate: Float between 0 and 1. Fraction of the input units to drop.
        name: Name of the model. Useful when having multiple TCN.

    Returns:
        A tuple where the first element is the residual model layer, and the second
        is the skip connection.
    """

    original_x = x
    conv = Conv1D(filters=nb_filters, kernel_size=kernel_size,
                  dilation_rate=i, padding=padding,
                  name=name + '_d_%s_conv_%d_tanh_s%d' % (padding, i, s))(x)
    if activation == 'norm_relu':
        x = Activation('relu')(conv)
        x = Lambda(channel_normalization)(x)
    elif activation == 'wavenet':
        x = wave_net_activation(conv)
    else:
        x = Activation(activation)(conv)

    x = SpatialDropout1D(dropout_rate, name=name + '_spatial_dropout1d_%d_s%d_%f' % (i, s, dropout_rate))(x)

    # 1x1 conv.
    x = Convolution1D(nb_filters, 1, padding='same')(x)
    res_x = tensorflow.keras.layers.add([original_x, x])
    return res_x, x


def process_dilations(dilations):
    def is_power_of_two(num):
        return num != 0 and ((num & (num - 1)) == 0)

    if all([is_power_of_two(i) for i in dilations]):
        return dilations

    else:
        new_dilations = [2 ** i for i in dilations]
        # print(f'Updated dilations from {dilations} to {new_dilations} because of backwards compatibility.')
        return new_dilations


class TCN:
    """Creates a TCN layer.

        Input shape:
            A tensor of shape (batch_size, timesteps, input_dim).

        Args:
            nb_filters: The number of filters to use in the convolutional layers.
            kernel_size: The size of the kernel to use in each convolutional layer.
            dilations: The list of the dilations. Example is: [1, 2, 4, 8, 16, 32, 64].
            nb_stacks : The number of stacks of residual blocks to use.
            activation: The activations to use (norm_relu, wavenet, relu...).
            padding: The padding to use in the convolutional layers, 'causal' or 'same'.
            use_skip_connections: Boolean. If we want to add skip connections from input to each residual block.
            return_sequences: Boolean. Whether to return the last output in the output sequence, or the full sequence.
            dropout_rate: Float between 0 and 1. Fraction of the input units to drop.
            name: Name of the model. Useful when having multiple TCN.

        Returns:
            A TCN layer.
        """

    def __init__(self,
                 nb_filters=64,
                 kernel_size=2,
                 nb_stacks=1,
                 dilations=[1, 2, 4, 8, 16],
                 activation='norm_relu',
                 padding='causal',
                 use_skip_connections=True,
                 dropout_rate=0.0,
                 return_sequences=True,
                 name='tcn'):
        self.name = name
        self.return_sequences = return_sequences
        self.dropout_rate = dropout_rate
        self.use_skip_connections = use_skip_connections
        self.activation = activation
        self.dilations = dilations
        self.nb_stacks = nb_stacks
        self.kernel_size = kernel_size
        self.nb_filters = nb_filters
        self.padding = padding

        if padding != 'causal' and padding != 'same':
            raise ValueError("Only 'causal' or 'same' padding are compatible for this layer.")

        if not isinstance(nb_filters, int):
            print('An interface change occurred after the version 2.1.2.')
            print('Before: tcn.TCN(i, return_sequences=False, ...)')
            print('Now should be: tcn.TCN(return_sequences=False, ...)(i)')
            print('Second solution is to pip install keras-tcn==2.1.2 to downgrade.')
            raise Exception()

    def __call__(self, inputs, Activation_of_skip_connections='selu'):
        x = inputs
        x = Convolution1D(self.nb_filters, 1, padding=self.padding, name=self.name + '_initial_conv')(x)
        skip_connections = []
        for s in range(self.nb_stacks):
            for i in self.dilations:
                x, skip_out = residual_block(x, s, i, self.activation, self.nb_filters,
                                             self.kernel_size, self.padding, self.dropout_rate, name=self.name)
                skip_connections.append(skip_out)
        if self.use_skip_connections:
            x = tensorflow.keras.layers.add(skip_connections)
        x = Activation(Activation_of_skip_connections)(x)

        if not self.return_sequences:
            output_slice_index = -1
            x = Lambda(lambda tt: tt[:, output_slice_index, :])(x)
        return x


def compiled_tcn(num_feat,  # type: int
                 num_classes,  # type: int
                 nb_filters,  # type: int
                 kernel_size,  # type: int
                 dilations,  # type: List[int]
                 nb_stacks,  # type: int
                 max_len,  # type: int
                 activation='norm_relu',  # type: str
                 padding='causal',  # type: str
                 use_skip_connections=True,  # type: bool
                 return_sequences=True,
                 regression=False,  # type: bool
                 dropout_rate=0.05,  # type: float
                 name='tcn'  # type: str
                 ):
    # type: (...) -> tensorflow.keras.Model
    """Creates a compiled TCN model for a given task (i.e. regression or classification).

    Args:
        num_feat: The number of features of your input, i.e. the last dimension of: (batch_size, timesteps, input_dim).
        num_classes: The size of the final dense layer, how many classes we are predicting.
        nb_filters: The number of filters to use in the convolutional layers.
        kernel_size: The size of the kernel to use in each convolutional layer.
        dilations: The list of the dilations. Example is: [1, 2, 4, 8, 16, 32, 64].
        nb_stacks : The number of stacks of residual blocks to use.
        max_len: The maximum sequence length, use None if the sequence length is dynamic.
        activation: The activations to use.
        padding: The padding to use in the convolutional layers.
        use_skip_connections: Boolean. If we want to add skip connections from input to each residual block.
        return_sequences: Boolean. Whether to return the last output in the output sequence, or the full sequence.
        regression: Whether the output should be continuous or discrete.
        dropout_rate: Float between 0 and 1. Fraction of the input units to drop.
        name: Name of the model. Useful when having multiple TCN.

    Returns:
        A compiled keras TCN.
    """

    dilations = process_dilations(dilations)

    input_layer = Input(shape=(max_len, num_feat))

    x = TCN(nb_filters, kernel_size, nb_stacks, dilations, activation,
            padding, use_skip_connections, dropout_rate, return_sequences, name)(input_layer)

    print('x.shape=', x.shape)

    if not regression:
        # classification
        x = Dense(num_classes)(x)
        x = Activation('softmax')(x)
        output_layer = x
        print(f'model.x = {input_layer.shape}')
        print(f'model.y = {output_layer.shape}')
        model = Model(input_layer, output_layer)

        # https://github.com/keras-team/keras/pull/11373
        # It's now in Keras@master but still not available with pip.
        # TODO To remove later.
        def accuracy(y_true, y_pred):
            # reshape in case it's in shape (num_samples, 1) instead of (num_samples,)
            if K.ndim(y_true) == K.ndim(y_pred):
                y_true = K.squeeze(y_true, -1)
            # convert dense predictions to labels
            y_pred_labels = K.argmax(y_pred, axis=-1)
            y_pred_labels = K.cast(y_pred_labels, K.floatx())
            return K.cast(K.equal(y_true, y_pred_labels), K.floatx())

        adam = optimizers.Adam(lr=0.002, clipnorm=1.)
        model.compile(adam, loss='sparse_categorical_crossentropy', metrics=[accuracy])
        print('Adam with norm clipping.')
    else:
        # regression
        x = Dense(1)(x)
        x = Activation('linear')(x)
        output_layer = x
        print(f'model.x = {input_layer.shape}')
        print(f'model.y = {output_layer.shape}')
        model = Model(input_layer, output_layer)
        adam = optimizers.Adam(lr=0.002, clipnorm=1.)
        model.compile(adam, loss=tf_stock_loss_8)

    return model

# %% [markdown]
# # loss func

# %%
def mean_squared_error(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true), axis=-1)

# %%
def tf_stock_loss_5(vex_sign,cave_sign):
    def loss(y_true, y_pred):
        y_pred_previous= tf.roll(y_pred, shift=-1, axis=0)
        rising = K.less(y_pred_previous,y_pred)
        falling = K.greater(y_pred_previous ,y_pred)
        convex= K.equal(vex_sign,tf.ones(shape = tf.shape(vex_sign)))
        concave= K.equal(cave_sign,tf.ones(shape = tf.shape(cave_sign)))
        losses = tf.keras.backend.cast(tf.logical_and(convex,rising),dtype='float32')*penalty* mean_squared_error(y_true, y_pred)+\
                 tf.keras.backend.cast(tf.logical_and(concave,falling),dtype='float32')*penalty*mean_squared_error(y_true, y_pred)+\
                 mean_squared_error(y_true, y_pred)
        #losses = K.all(K.stack([convex, rising], axis=0), axis=0)*penalty* mean_squared_error(y_true, y_pred)+mean_squared_error(y_true, y_pred)
        """K.all(K.stack([concave, falling], axis=0), axis=0)*penalty** mean_squared_error(y_true, y_pred)+"""
        return losses
    return loss

# %%
def tf_stock_loss_6(vex_sign,cave_sign):
    def loss(y_true, y_pred):
        y_pred_tobemodified0= tf.reshape(y_pred, [-1])
        y_pred_tobemodified1= tf.roll(y_pred_tobemodified0, shift=1, axis=0)
        y_pred_previous= tf.reshape(y_pred_tobemodified1,tf.shape(y_pred))
        
        rising = K.less(y_pred_previous,y_pred)
        falling = K.greater(y_pred_previous ,y_pred)
        y_pred_falling= K.equal(vex_sign,tf.ones(shape = tf.shape(vex_sign)))
        y_pred_rising= K.equal(cave_sign,tf.ones(shape = tf.shape(cave_sign)))
        losses = tf.keras.backend.cast(tf.logical_and(y_pred_falling,rising),dtype='float32')*penalty* mean_squared_error(y_true, y_pred)+\
                 tf.keras.backend.cast(tf.logical_and(y_pred_rising,falling),dtype='float32')*penalty*mean_squared_error(y_true, y_pred)+\
                 mean_squared_error(y_true, y_pred)       
        return losses
    return loss

# %%
def tf_stock_loss_7(vex_sign,cave_sign):
    def loss(y_true, y_pred):
        
        y_pred_tobemodified0= tf.reshape(y_pred, [-1])
        y_pred_tobemodified1= tf.roll(y_pred_tobemodified0, shift=1, axis=0)
        y_pred_previous= tf.reshape(y_pred_tobemodified1,tf.shape(y_pred))
        
        y_pred_rising = K.less(y_pred_previous,y_pred)
        y_pred_falling = K.greater(y_pred_previous ,y_pred)    

        y_true_tobemodified0= tf.reshape(y_true, [-1])
        y_true_tobemodified1= tf.roll(y_true_tobemodified0, shift=1, axis=0)
        y_true_previous= tf.reshape(y_true_tobemodified1,tf.shape(y_true))
                                                                  
        y_true_rising = K.less(y_true_previous,y_true)
        y_true_falling = K.greater(y_true_previous ,y_true)

        losses = tf.keras.backend.cast(tf.logical_and(y_true_falling,y_pred_rising),dtype='float32')*penalty* mean_squared_error(y_true, y_pred)+\
                 tf.keras.backend.cast(tf.logical_and(y_true_rising,y_pred_falling),dtype='float32')*penalty*mean_squared_error(y_true, y_pred)+\
                 mean_squared_error(y_true, y_pred)       
        return losses
    return loss

# %%
def tf_stock_loss_8(y_true, y_pred):
    #indices = tf.constant([[0]])
    #updates = tf.constant([False])
    indices = tf.constant([[[0,0],[0,1],[0,2],[0,3],[0,4]]])
    updates = tf.constant([[False],[False],[False],[False],[False]])

    y_pred_tobemodified0= tf.reshape(y_pred, [-1])
    y_pred_tobemodified1= tf.roll(y_pred_tobemodified0, shift=5, axis=0)
    y_pred_previous= tf.reshape(y_pred_tobemodified1,tf.shape(y_pred))

    y_pred_rising0 = K.less(y_pred_previous,y_pred)
    y_pred_falling0 = K.greater(y_pred_previous ,y_pred)    
    y_pred_rising = tf.tensor_scatter_update(y_pred_rising0, indices, updates)
    y_pred_falling = tf.tensor_scatter_update(y_pred_falling0, indices, updates)

    y_true_tobemodified0= tf.reshape(y_true, [-1])
    y_true_tobemodified1= tf.roll(y_true_tobemodified0, shift=5, axis=0)
    y_true_previous= tf.reshape(y_true_tobemodified1,tf.shape(y_true))

    y_true_rising0 = K.less(y_true_previous,y_true)
    y_true_falling0 = K.greater(y_true_previous ,y_true)
    y_true_rising = tf.tensor_scatter_update(y_true_rising0, indices, updates)
    y_true_falling = tf.tensor_scatter_update(y_true_falling0, indices, updates)

    loss = tf.keras.backend.cast(tf.logical_and(y_true_falling,y_pred_rising),dtype='float32')*penalty* mean_squared_error(y_true, y_pred)+\
             tf.keras.backend.cast(tf.logical_and(y_true_rising,y_pred_falling),dtype='float32')*penalty*mean_squared_error(y_true, y_pred)+\
             mean_squared_error(y_true, y_pred)       

    return loss

# %%
def custom_r2_score(file_name):
    Target_DirPath = 'Deep-Learning-in-Python-master/'
    file_end_with = '_lr0001_dila16.csv'
    #above need to be adjust
    df_for_eval= pd.read_csv(Target_DirPath + file_name + file_end_with)
    df_for_eval['Date'] = pd.to_datetime(df_for_eval["Date"])
    df_for_eval = df_for_eval.set_index(["Date"], drop=True)

    y_pred_for_eval = df_for_eval["Close"]
    print(y_pred_for_eval.shape)
    ## create empty table with label fields
    y_pred_for_eval_data_like = np.zeros(shape=(len(y_pred_for_eval), X_train.shape[1]))
    ## put the predicted values in the right field
    y_pred_for_eval_data_like[:,0] = y_pred_for_eval[:]
    ## transform and then select the right field
    y_pred_for_eval_data = sc.transform(y_pred_for_eval_data_like)[:,0]

    r2_test = r2_score(y_test, y_pred_for_eval_data)
    print("The Adjusted R2 score on the Test set is:\t{:0.3f}"\
              .format(adj_r2_score(r2_test, X_test.shape[0], X_test.shape[1])))

    y_test_diff = np.diff(y_test) #y_test[i]與y_test[i-1]差異
    y_pred_for_eval_data_diff = np.diff(y_pred_for_eval_data)#y_pred[i]與y_pred[i-1]差異
    rsquare_product = y_test_diff*y_pred_for_eval_data_diff #兩者相乘
    def return_same_sign_bool(d):
        d = np.array(d)
        return np.where(d > 0, 1, 0)
    rsquare_product_bool = return_same_sign_bool(rsquare_product) #如果兩者相乘為正數回傳1，非正數回傳0
    print("The Custom  sign score on the Test set is:\t{:0.3f}"\
              .format((int(sum(rsquare_product_bool)) / len(rsquare_product_bool)))) 
               #計算y_test及y_pred變動同向機率
    print("The Custom  R2 score on the Test set is:\t{:0.3f}"\
              .format(adj_r2_score(r2_test, X_test.shape[0], X_test.shape[1])/2 
                      + ((int(sum(rsquare_product_bool)) / len(rsquare_product_bool)))/2 ))

# %% [markdown]
# # tcn9~11 change filter size pe0.01

# %%
#tcn9
file_name='NYA_de5_try2_clf5_pe0.01_tcn9'
penalty=0.01

# %%
X_tr_t = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_tst_t = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])


input_tensor= Input(shape=(1,X_train.shape[1],))
output = TCN(nb_filters=512, kernel_size=2, nb_stacks=1, dilations=[1, 2, 4, 8, 16], \
        activation='selu', padding='causal', use_skip_connections=True,\
        dropout_rate=0.3, return_sequences=False, name='tcn')(input_tensor)  # The TCN layers are here.

output_tensor = Dense(1)(output)
model = Model([input_tensor], output_tensor)
model.compile(optimizer=Adam(lr=0.0001, clipnorm=1, clipvalue=0.5), loss=tf_stock_loss_8)
model.summary()
early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
history_model = model.fit(x=[X_tr_t], y=y_train, epochs=300, 
                                    batch_size=16, verbose=1,
                                    validation_split= val_split_ratio, callbacks=[CSV(losspath=losspath, file_name=file_name)],
                                    shuffle=False)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1, 48)]      0
# __________________________________________________________________________________________________
# tcn_initial_conv (Conv1D)       (None, 1, 512)       25088       input_1[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_1_tanh_s0 (Co (None, 1, 512)       524800      tcn_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1, 512)       0           tcn_d_causal_conv_1_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_1_s0_0.30 (None, 1, 512)       0           activation[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 1, 512)       262656      tcn_spatial_dropout1d_1_s0_0.3000
# __________________________________________________________________________________________________
# add (Add)                       (None, 1, 512)       0           tcn_initial_conv[0][0]
#                                                                  conv1d[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_2_tanh_s0 (Co (None, 1, 512)       524800      add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 512)       0           tcn_d_causal_conv_2_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_2_s0_0.30 (None, 1, 512)       0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 1, 512)       262656      tcn_spatial_dropout1d_2_s0_0.3000
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 512)       0           add[0][0]
#                                                                  conv1d_1[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_4_tanh_s0 (Co (None, 1, 512)       524800      add_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 512)       0           tcn_d_causal_conv_4_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_4_s0_0.30 (None, 1, 512)       0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1, 512)       262656      tcn_spatial_dropout1d_4_s0_0.3000
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1, 512)       0           add_1[0][0]
#                                                                  conv1d_2[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_8_tanh_s0 (Co (None, 1, 512)       524800      add_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 512)       0           tcn_d_causal_conv_8_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_8_s0_0.30 (None, 1, 512)       0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1, 512)       262656      tcn_spatial_dropout1d_8_s0_0.3000
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1, 512)       0           add_2[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_16_tanh_s0 (C (None, 1, 512)       524800      add_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 512)       0           tcn_d_causal_conv_16_tanh_s0[0][0
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_16_s0_0.3 (None, 1, 512)       0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 1, 512)       262656      tcn_spatial_dropout1d_16_s0_0.300
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 1, 512)       0           conv1d[0][0]
#                                                                  conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
#                                                                  conv1d_3[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1, 512)       0           add_5[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            513         lambda[0][0]
# ==================================================================================================
# Total params: 3,962,881
# Trainable params: 3,962,881
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 6808 samples, validate on 757 samples
# Epoch 1/300
# 6808/6808==============================] - 8s 1ms/sample - loss: 0.4699 - val_loss: 0.3212
# Epoch 2/300
# 6808/6808==============================] - 5s 771us/sample - loss: 0.0849 - val_loss: 0.0403
# Epoch 3/300
# 6808/6808==============================] - 5s 768us/sample - loss: 0.0424 - val_loss: 0.0692
# Epoch 4/300
# 6808/6808==============================] - 5s 766us/sample - loss: 0.0225 - val_loss: 0.0082 loss:  - ETA - ETA: 0s - loss:  - ETA: 0s - lo
# Epoch 5/300
# 6808/6808==============================] - 5s 767us/sample - loss: 0.0223 - val_loss: 0.0229
# Epoch 6/300
# 6808/6808==============================] - 5s 763us/sample - loss: 0.0125 - val_loss: 0.0892A: 0s - loss: 0.0
# Epoch 7/300
# 6808/6808==============================] - 5s 766us/sample - loss: 0.0104 - val_loss: 0.0464
# Epoch 8/300
# 6808/6808==============================] - 5s 766us/sample - loss: 0.0080 - val_loss: 0.0331
# Epoch 9/300
# 6808/6808==============================] - 5s 773us/sample - loss: 0.0076 - val_loss: 0.0243 0.
# Epoch 10/300
# 6808/6808==============================] - 5s 764us/sample - loss: 0.0066 - val_loss: 0.0275
# Epoch 11/300
# 6808/6808==============================] - 5s 771us/sample - loss: 0.0068 - val_loss: 0.0441
# Epoch 12/300
# 6808/6808==============================] - 5s 775us/sample - loss: 0.0061 - val_loss: 0.0272
# Epoch 13/300
# 6808/6808==============================] - 5s 769us/sample - loss: 0.0048 - val_loss: 0.0381
# Epoch 14/300
# 6808/6808==============================] - 5s 766us/sample - loss: 0.0062 - val_loss: 0.0343
# Epoch 15/300
# 6808/6808==============================] - 5s 767us/sample - loss: 0.0046 - val_loss: 0.0373
# Epoch 16/300
# 6808/6808==============================] - 5s 769us/sample - loss: 0.0036 - val_loss: 0.0300
# Epoch 17/300
# 6808/6808==============================] - 5s 766us/sample - loss: 0.0040 - val_loss: 0.0352
# Epoch 18/300
# 6808/6808==============================] - 5s 765us/sample - loss: 0.0032 - val_loss: 0.0242
# Epoch 19/300
# 6808/6808==============================] - 5s 765us/sample - loss: 0.0036 - val_loss: 0.0429
# Epoch 20/300
# 6808/6808==============================] - 5s 768us/sample - loss: 0.0036 - val_loss: 0.0485s: 0.005 -  - ETA: 0s - los
# Epoch 21/300
# 6808/6808==============================] - 5s 768us/sample - loss: 0.0028 - val_loss: 0.0358
# Epoch 22/300
# 6808/6808==============================] - 5s 766us/sample - loss: 0.0036 - val_loss: 0.0209
# Epoch 23/300
# 6808/6808==============================] - 5s 766us/sample - loss: 0.0026 - val_loss: 0.0375
# Epoch 24/300
# 6808/6808==============================] - 5s 762us/sample - loss: 1.2286e-04 - val_loss: 0.0023
# Epoch 295/300
# 6808/6808==============================] - 5s 758us/sample - loss: 1.2099e-04 - val_loss: 0.0031
# Epoch 296/300
# 6808/6808==============================] - 5s 757us/sample - loss: 1.1423e-04 - val_loss: 0.0031
# Epoch 297/300
# 6808/6808==============================] - 5s 759us/sample - loss: 1.1318e-04 - val_loss: 0.0033
# Epoch 298/300
# 6808/6808==============================] - 5s 758us/sample - loss: 1.1753e-04 - val_loss: 0.0037
# Epoch 299/300
# 6808/6808==============================] - 5s 761us/sample - loss: 1.1726e-04 - val_loss: 0.0036
# Epoch 300/300
# 6808/6808==============================] - 5s 759us/sample - loss: 1.1728e-04 - val_loss: 0.0032

# %%
plot_model_architecture(model=model, file_name=file_name)
y_pred = predict_image(history_model=history_model,X_tst_t=X_tst_t,input_tensor=input_tensor,
                  
                  predict_imagepath=predict_imagepath, file_name=file_name)
loss_image(history_model=history_model, loss_imagepath=loss_imagepath, file_name=file_name)
save_csv(y_pred=y_pred,X_train=X_train,X_test=X_test,Target_DirPath=Target_DirPath,
             file_name=file_name,test_date=test_date)
save_train_csv(file_name=file_name)
# Out:
# y_pred.shape: (1756, 1)
# y_test_rsquare.shape: (1756,)
# R-Squared: 0.936823
# The Adjusted R2 score on the Test set is:	0.935
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# # custom r2 score

# %%
for iter_number in range(9,10):
    iter_number = str(iter_number)
    file_name='NYA_de5_try2_clf5_pe0.01_tcn'+iter_number
    print(file_name+":")
    custom_r2_score(file_name)
# Out:
# NYA_de5_clf5_pe0.01_tcn9:
# (1756,)
# The Adjusted R2 score on the Test set is:	0.935
# The Custom  sign score on the Test set is:	0.500
# The Custom  R2 score on the Test set is:	0.718

# %%
#tcn9
file_name='NYA_de5_try2_clf5_pe0.1_tcn9'
penalty=0.1

# %%
X_tr_t = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_tst_t = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])


input_tensor= Input(shape=(1,X_train.shape[1],))
output = TCN(nb_filters=512, kernel_size=2, nb_stacks=1, dilations=[1, 2, 4, 8, 16], \
        activation='selu', padding='causal', use_skip_connections=True,\
        dropout_rate=0.3, return_sequences=False, name='tcn')(input_tensor)  # The TCN layers are here.

output_tensor = Dense(1)(output)
model = Model([input_tensor], output_tensor)
model.compile(optimizer=Adam(lr=0.0001, clipnorm=1, clipvalue=0.5), loss=tf_stock_loss_8)
model.summary()
early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
history_model = model.fit(x=[X_tr_t], y=y_train, epochs=300, 
                                    batch_size=16, verbose=1,
                                    validation_split= val_split_ratio, callbacks=[CSV(losspath=losspath, file_name=file_name)],
                                    shuffle=False)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 1, 48)]      0
# __________________________________________________________________________________________________
# tcn_initial_conv (Conv1D)       (None, 1, 512)       25088       input_2[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_1_tanh_s0 (Co (None, 1, 512)       524800      tcn_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1, 512)       0           tcn_d_causal_conv_1_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_1_s0_0.30 (None, 1, 512)       0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 1, 512)       262656      tcn_spatial_dropout1d_1_s0_0.3000
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 1, 512)       0           tcn_initial_conv[0][0]
#                                                                  conv1d_5[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_2_tanh_s0 (Co (None, 1, 512)       524800      add_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 1, 512)       0           tcn_d_causal_conv_2_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_2_s0_0.30 (None, 1, 512)       0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 1, 512)       262656      tcn_spatial_dropout1d_2_s0_0.3000
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 1, 512)       0           add_6[0][0]
#                                                                  conv1d_6[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_4_tanh_s0 (Co (None, 1, 512)       524800      add_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1, 512)       0           tcn_d_causal_conv_4_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_4_s0_0.30 (None, 1, 512)       0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 1, 512)       262656      tcn_spatial_dropout1d_4_s0_0.3000
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1, 512)       0           add_7[0][0]
#                                                                  conv1d_7[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_8_tanh_s0 (Co (None, 1, 512)       524800      add_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 1, 512)       0           tcn_d_causal_conv_8_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_8_s0_0.30 (None, 1, 512)       0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 1, 512)       262656      tcn_spatial_dropout1d_8_s0_0.3000
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 1, 512)       0           add_8[0][0]
#                                                                  conv1d_8[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_16_tanh_s0 (C (None, 1, 512)       524800      add_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_16_tanh_s0[0][0
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_16_s0_0.3 (None, 1, 512)       0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 1, 512)       262656      tcn_spatial_dropout1d_16_s0_0.300
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 1, 512)       0           conv1d_5[0][0]
#                                                                  conv1d_6[0][0]
#                                                                  conv1d_7[0][0]
#                                                                  conv1d_8[0][0]
#                                                                  conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1, 512)       0           add_11[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           activation_11[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            513         lambda_1[0][0]
# ==================================================================================================
# Total params: 3,962,881
# Trainable params: 3,962,881
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 6808 samples, validate on 757 samples
# Epoch 1/300
# 6808/6808==============================] - 7s 1ms/sample - loss: 0.5907 - val_loss: 0.1109
# Epoch 2/300
# 6808/6808==============================] - 5s 802us/sample - loss: 0.0884 - val_loss: 0.3154
# Epoch 3/300
# 6808/6808==============================] - 5s 808us/sample - loss: 0.0456 - val_loss: 0.3116
# Epoch 4/300
# 6808/6808==============================] - 5s 799us/sample - loss: 0.0294 - val_loss: 0.1364ETA: 0s - loss: 0
# Epoch 5/300
# 6808/6808==============================] - 5s 804us/sample - loss: 0.0195 - val_loss: 0.1248
# Epoch 6/300
# 6808/6808==============================] - 5s 804us/sample - loss: 0.0131 - val_loss: 0.0890
# Epoch 7/300
# 6808/6808==============================] - 5s 802us/sample - loss: 0.0123 - val_loss: 0.0807
# Epoch 8/300
# 6808/6808==============================] - 5s 802us/sample - loss: 0.0077 - val_loss: 0.0088- loss: 0 - ETA: 2s - ETA: 0s - loss:
# Epoch 9/300
# 6808/6808==============================] - 5s 802us/sample - loss: 0.0072 - val_loss: 0.0621
# Epoch 10/300
# 6808/6808==============================] - 5s 800us/sample - loss: 0.0068 - val_loss: 0.0090
# Epoch 11/300
# 6808/6808==============================] - 5s 800us/sample - loss: 0.0073 - val_loss: 0.0214
# Epoch 12/300
# 6808/6808==============================] - 5s 801us/sample - loss: 0.0054 - val_loss: 0.0307
# Epoch 13/300
# 6808/6808==============================] - 6s 808us/sample - loss: 0.0045 - val_loss: 0.0228
# Epoch 14/300
# 6808/6808==============================] - 5s 806us/sample - loss: 0.0052 - val_loss: 0.0350 - ETA: 2 - E
# Epoch 15/300
# 6808/6808==============================] - 5s 803us/sample - loss: 0.0052 - val_loss: 0.0512- loss: 0. - ETA: 3s - loss: 0.008 - ETA:  - ETA: 2s - loss: 0 - ETA: 2s - -
# Epoch 16/300
# 6808/6808==============================] - 5s 799us/sample - loss: 0.0046 - val_loss: 0.0517
# Epoch 17/300
# 6808/6808==============================] - 5s 801us/sample - loss: 0.0048 - val_loss: 0.0405
# Epoch 18/300
# 6808/6808==============================] - 5s 803us/sample - loss: 0.0037 - val_loss: 0.0288 2s - loss: 0.0 - E
# Epoch 19/300
# 6808/6808==============================] - 5s 802us/sample - loss: 0.0034 - val_loss: 0.0375-  - ETA: 0s
# Epoch 20/300
# 6808/6808==============================] - 5s 801us/sample - loss: 0.0035 - val_loss: 0.0077s - loss: -  - ETA: 0s
# Epoch 21/300
# 6808/6808==============================] - 5s 799us/sample - loss: 0.0024 - val_loss: 0.0404
# Epoch 22/300
# 6808/6808==============================] - 5s 800us/sample - loss: 0.0040 - val_loss: 0.0286
# Epoch 23/300
# 6808/6808==============================] - 5s 801us/sample - loss: 0.0025 - val_loss: 0.0328 - ETA: 1s - lo - ETA: 1s - loss: 0 - ETA: 0s
# Epoch 24/300
# 6808/6808==============================] - 5s 803us/sample - loss: 0.0026 - val_loss: 0.0275 loss: 0.00 - ETA: 2s - loss:  - ET -
# Epoch 25/300
# 6808/6808==============================] - 5s 802us/sample - loss: 0.0020 - val_loss: 0.0151
# Epoch 26/300
# 6808/6808==============================] - 5s 801us/sample - loss: 0.0017 - val_loss: 0.0513ss: 0.
# Epoch 27/300
# 6808/6808==============================] - 5s 803us/sample - loss: 0.
300
# 6808/6808==============================] - 5s 803us/sample - loss: 1.2921e-04 - val_loss: 0.0020
# Epoch 299/300
# 6808/6808==============================] - 5s 803us/sample - loss: 1.3328e-04 - val_loss: 0.0020A: 1s - loss: 9.00 - ETA: 0s - loss: 1.1610e- - ETA: 0s - l
# Epoch 300/300
# 6808/6808==============================] - 5s 804us/sample - loss: 1.3021e-04 - val_loss: 0.0017

# %%
plot_model_architecture(model=model, file_name=file_name)
y_pred = predict_image(history_model=history_model,X_tst_t=X_tst_t,input_tensor=input_tensor,
                  
                  predict_imagepath=predict_imagepath, file_name=file_name)
loss_image(history_model=history_model, loss_imagepath=loss_imagepath, file_name=file_name)
save_csv(y_pred=y_pred,X_train=X_train,X_test=X_test,Target_DirPath=Target_DirPath,
             file_name=file_name,test_date=test_date)
save_train_csv(file_name=file_name)
# Out:
# y_pred.shape: (1756, 1)
# y_test_rsquare.shape: (1756,)
# R-Squared: 0.948517
# The Adjusted R2 score on the Test set is:	0.947
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# # custom r2 score

# %%
for iter_number in range(9,10):
    iter_number = str(iter_number)
    file_name='NYA_de5_try2_clf5_pe0.1_tcn'+iter_number
    print(file_name+":")
    custom_r2_score(file_name)
# Out:
# NYA_de5_clf5_pe0.1_tcn9:
# (1756,)
# The Adjusted R2 score on the Test set is:	0.947
# The Custom  sign score on the Test set is:	0.507
# The Custom  R2 score on the Test set is:	0.727

# %%
#tcn9
file_name='NYA_de5_try2_clf5_pe1_tcn9'
penalty=1

# %%
X_tr_t = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_tst_t = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])


input_tensor= Input(shape=(1,X_train.shape[1],))
output = TCN(nb_filters=512, kernel_size=2, nb_stacks=1, dilations=[1, 2, 4, 8, 16], \
        activation='selu', padding='causal', use_skip_connections=True,\
        dropout_rate=0.3, return_sequences=False, name='tcn')(input_tensor)  # The TCN layers are here.

output_tensor = Dense(1)(output)
model = Model([input_tensor], output_tensor)
model.compile(optimizer=Adam(lr=0.0001, clipnorm=1, clipvalue=0.5), loss=tf_stock_loss_8)
model.summary()
early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
history_model = model.fit(x=[X_tr_t], y=y_train, epochs=300, 
                                    batch_size=16, verbose=1,
                                    validation_split= val_split_ratio, callbacks=[CSV(losspath=losspath, file_name=file_name)],
                                    shuffle=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 1, 48)]      0
# __________________________________________________________________________________________________
# tcn_initial_conv (Conv1D)       (None, 1, 512)       25088       input_3[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_1_tanh_s0 (Co (None, 1, 512)       524800      tcn_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_1_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_1_s0_0.30 (None, 1, 512)       0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_1_s0_0.3000
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 1, 512)       0           tcn_initial_conv[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_2_tanh_s0 (Co (None, 1, 512)       524800      add_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_2_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_2_s0_0.30 (None, 1, 512)       0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_2_s0_0.3000
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 1, 512)       0           add_12[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_4_tanh_s0 (Co (None, 1, 512)       524800      add_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_4_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_4_s0_0.30 (None, 1, 512)       0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_4_s0_0.3000
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 1, 512)       0           add_13[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_8_tanh_s0 (Co (None, 1, 512)       524800      add_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_8_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_8_s0_0.30 (None, 1, 512)       0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_8_s0_0.3000
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 1, 512)       0           add_14[0][0]
#                                                                  conv1d_13[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_16_tanh_s0 (C (None, 1, 512)       524800      add_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_16_tanh_s0[0][0
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_16_s0_0.3 (None, 1, 512)       0           activation_16[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_16_s0_0.300
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 1, 512)       0           conv1d_10[0][0]
#                                                                  conv1d_11[0][0]
#                                                                  conv1d_12[0][0]
#                                                                  conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 1, 512)       0           add_17[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           activation_17[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            513         lambda_2[0][0]
# ==================================================================================================
# Total params: 3,962,881
# Trainable params: 3,962,881
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 6808 samples, validate on 757 samples
# Epoch 1/300
# 6808/6808==============================] - 7s 1ms/sample - loss: 0.7763 - val_loss: 0.0590
# Epoch 2/300
# 6808/6808==============================] - 6s 811us/sample - loss: 0.1257 - val_loss: 0.0971 ETA: 0s - loss: - ETA: 0s - loss:
# Epoch 3/300
# 6808/6808==============================] - 6s 812us/sample - loss: 0.0631 - val_loss: 0.0808
# Epoch 4/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.0404 - val_loss: 0.0797
# Epoch 5/300
# 6808/6808==============================] - 5s 803us/sample - loss: 0.0244 - val_loss: 0.1029
# Epoch 6/300
# 6808/6808==============================] - 5s 799us/sample - loss: 0.0202 - val_loss: 0.0134
# Epoch 7/300
# 6808/6808==============================] - 5s 804us/sample - loss: 0.0178 - val_loss: 0.2260
# Epoch 8/300
# 6808/6808==============================] - 6s 808us/sample - loss: 0.0144 - val_loss: 0.0239
# Epoch 9/300
# 6808/6808==============================] - 6s 811us/sample - loss: 0.0108 - val_loss: 0.1289
# Epoch 10/300
# 6808/6808==============================] - 6s 811us/sample - loss: 0.0090 - val_loss: 0.0418
# Epoch 11/300
# 6808/6808==============================] - 6s 811us/sample - loss: 0.0106 - val_loss: 0.0277
# Epoch 12/300
# 6808/6808==============================] - 6s 812us/sample - loss: 0.0078 - val_loss: 0.0216
# Epoch 13/300
# 6808/6808==============================] - ETA: 0s - loss: 0.006 - 6s 810us/sample - loss: 0.0063 - val_loss: 0.0273
# Epoch 14/300
# 6808/6808==============================] - ETA: 0s - loss: 0.005 - 6s 811us/sample - loss: 0.0059 - val_loss: 0.0996
# Epoch 15/300
# 6808/6808==============================] - 6s 809us/sample - loss: 0.0084 - val_loss: 0.028500 - ETA: 1s - loss: - ETA: - ETA: 0s - loss:
# Epoch 16/300
# 6808/6808==============================] - 6s 811us/sample - loss: 0.0051 - val_loss: 0.0611TA: 0s
# Epoch 17/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.0059 - val_loss: 0.0252
# Epoch 18/300
# 6808/6808==============================] - 6s 811us/sample - loss: 0.0057 - val_loss: 0.0187TA: 3s - loss: 0. - ETA: 3s - loss: - ETA: 2s - - ETA: 2s - l
# Epoch 19/300
# 6808/6808==============================] - 6s 815us/sample - loss: 0.0043 - val_loss: 0.0118
# Epoch 20/300
# 6808/6808==============================] - 6s 812us/sample - loss: 0.0031 - val_loss: 0.0217
# Epoch 21/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.0046 - val_loss: 0.0372A - ETA: 0s - loss: 0.0
# Epoch 22/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.0044 - val_loss: 0.0368o - ETA: 2s - ETA: 2s - loss: 0. - ETA: 1s - loss:  - ETA: 1s - l - ETA: 0
# Epoch 23/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.0025 - val_loss: 0.0269
# Epoch 24/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.0031 - val_loss: 0.0184l
# Epoch 25/300
# 6808/6808==============================] - 6s 811us/sample - loss: 0.0039 - val_loss: 0.0211
# Epoch 26/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.0030 - val_loss: 0.0318 ETA: 0
# Epoch 27/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.0023 - val_loss: 0.0322:  - ETA: 3s - loss:  - ETA: 3s -
# Epoch 28/300
# 6808/6808==============================] - 6s 809us/sample - loss: 0.0033 - val_loss: 0.0311
# Epoch 29/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.0021 - val_loss: 0.0319
# Epoch 30/300
# 6808/6808==============================] - 6s 811us/sample - loss: 0.0019 - val_loss: 0.0582 0s -
# Epoch 31/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.0017 - val_loss: 0.0352s: 0.001  - E
# Epoch 32/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.0019 - val_loss: 0.0368
# Epoch 33/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.
300
# 6808/6808==============================] - 6s 816us/sample - loss: 1.7414e-04 - val_loss: 0.0027
# Epoch 281/300
# 6808/6808==============================] - 6s 818us/sample - loss: 1.8020e-04 - val_loss: 0.0031
# Epoch 282/300
# 6808/6808==============================] - 6s 816us/sample - loss: 1.8431e-04 - val_loss: 0.0036A: 1s - loss: 1.2434e- - ETA:
# Epoch 283/300
# 6808/6808==============================] - 6s 817us/sample - loss: 1.8634e-04 - val_loss: 0.0034
# Epoch 284/300
# 6808/6808==============================] - 6s 820us/sample - loss: 1.9206e-04 - val_loss: 0.0031
# Epoch 285/300
# 6808/6808==============================] - 6s 818us/sample - loss: 1.8062e-04 - val_loss: 0.0035
# Epoch 286/300
# 6808/6808==============================] - 6s 818us/sample - loss: 1.8452e-04 - val_loss: 0.0039
# Epoch 287/300
# 6808/6808==============================] - 6s 819us/sample - loss: 1.9097e-04 - val_loss: 0.0027
# Epoch 288/300
# 6808/6808==============================] - 6s 813us/sample - loss: 1.8099e-04 - val_loss: 0.0035
# Epoch 289/300
# 6808/6808==============================] - 6s 818us/sample - loss: 1.8141e-04 - val_loss: 0.0031
# Epoch 290/300
# 6808/6808==============================] - 6s 818us/sample - loss: 1.8127e-04 - val_loss: 0.0032- loss: 4.0679e-0 - ETA: 2s -  - ETA: 1s - loss:  - ETA: 1
# Epoch 291/300
# 6808/6808==============================] - 6s 818us/sample - loss: 1.8359e-04 - val_loss: 0.0034
# Epoch 292/300
# 6808/6808==============================] - 6s 818us/sample - loss: 1.8455e-04 - val_loss: 0.0039 - ETA: 0s - loss: 1.67
# Epoch 293/300
# 6808/6808==============================] - 6s 819us/sample - loss: 1.7564e-04 - val_loss: 0.0039
# Epoch 294/300
# 6808/6808==============================] - 6s 818us/sample - loss: 1.8272e-04 - val_loss: 0.0036
# Epoch 295/300
# 6808/6808==============================] - 6s 816us/sample - loss: 1.7239e-04 - val_loss: 0.0034
# Epoch 296/300
# 6808/6808==============================] - 6s 818us/sample - loss: 1.9365e-04 - val_loss: 0.0031
# Epoch 297/300
# 6808/6808==============================] - 6s 813us/sample - loss: 1.8088e-04 - val_loss: 0.0035
# Epoch 298/300
# 6808/6808==============================] - 6s 815us/sample - loss: 1.9236e-04 - val_loss: 0.0037
# Epoch 299/300
# 6808/6808==============================] - 6s 818us/sample - loss: 1.8636e-04 - val_loss: 0.0032A: 3s - loss: 4.7858e - ETA: 3s - loss: 4.9696e- - ETA:  - ETA: 2s - l - ETA:
# Epoch 300/300
# 6808/6808==============================] - 6s 818us/sample - loss: 1.8395e-04 - val_loss: 0.0030

# %%
plot_model_architecture(model=model, file_name=file_name)
y_pred = predict_image(history_model=history_model,X_tst_t=X_tst_t,input_tensor=input_tensor,
                  
                  predict_imagepath=predict_imagepath, file_name=file_name)
loss_image(history_model=history_model, loss_imagepath=loss_imagepath, file_name=file_name)
save_csv(y_pred=y_pred,X_train=X_train,X_test=X_test,Target_DirPath=Target_DirPath,
             file_name=file_name,test_date=test_date)
save_train_csv(file_name=file_name)
# Out:
# y_pred.shape: (1756, 1)
# y_test_rsquare.shape: (1756,)
# R-Squared: 0.886015
# The Adjusted R2 score on the Test set is:	0.883
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# # custom r2 score

# %%
for iter_number in range(9,10):
    iter_number = str(iter_number)
    file_name='NYA_de5_try2_clf5_pe1_tcn'+iter_number
    print(file_name+":")
    custom_r2_score(file_name)
# Out:
# NYA_de5_clf5_pe1_tcn9:
# (1756,)
# The Adjusted R2 score on the Test set is:	0.883
# The Custom  sign score on the Test set is:	0.497
# The Custom  R2 score on the Test set is:	0.690

# %%
#tcn9
file_name='NYA_de5_try2_clf5_pe10_tcn9'
penalty=10

# %%
X_tr_t = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_tst_t = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])


input_tensor= Input(shape=(1,X_train.shape[1],))
output = TCN(nb_filters=512, kernel_size=2, nb_stacks=1, dilations=[1, 2, 4, 8, 16], \
        activation='selu', padding='causal', use_skip_connections=True,\
        dropout_rate=0.3, return_sequences=False, name='tcn')(input_tensor)  # The TCN layers are here.

output_tensor = Dense(1)(output)
model = Model([input_tensor], output_tensor)
model.compile(optimizer=Adam(lr=0.0001, clipnorm=1, clipvalue=0.5), loss=tf_stock_loss_8)
model.summary()
early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
history_model = model.fit(x=[X_tr_t], y=y_train, epochs=300, 
                                    batch_size=16, verbose=1,
                                    validation_split= val_split_ratio, callbacks=[CSV(losspath=losspath, file_name=file_name)],
                                    shuffle=False)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 1, 48)]      0
# __________________________________________________________________________________________________
# tcn_initial_conv (Conv1D)       (None, 1, 512)       25088       input_4[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_1_tanh_s0 (Co (None, 1, 512)       524800      tcn_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_1_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_1_s0_0.30 (None, 1, 512)       0           activation_18[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_1_s0_0.3000
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 1, 512)       0           tcn_initial_conv[0][0]
#                                                                  conv1d_15[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_2_tanh_s0 (Co (None, 1, 512)       524800      add_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_2_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_2_s0_0.30 (None, 1, 512)       0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_2_s0_0.3000
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 1, 512)       0           add_18[0][0]
#                                                                  conv1d_16[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_4_tanh_s0 (Co (None, 1, 512)       524800      add_19[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_4_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_4_s0_0.30 (None, 1, 512)       0           activation_20[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_4_s0_0.3000
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 1, 512)       0           add_19[0][0]
#                                                                  conv1d_17[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_8_tanh_s0 (Co (None, 1, 512)       524800      add_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_8_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_8_s0_0.30 (None, 1, 512)       0           activation_21[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_8_s0_0.3000
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 1, 512)       0           add_20[0][0]
#                                                                  conv1d_18[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_16_tanh_s0 (C (None, 1, 512)       524800      add_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_16_tanh_s0[0][0
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_16_s0_0.3 (None, 1, 512)       0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_16_s0_0.300
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 1, 512)       0           conv1d_15[0][0]
#                                                                  conv1d_16[0][0]
#                                                                  conv1d_17[0][0]
#                                                                  conv1d_18[0][0]
#                                                                  conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 1, 512)       0           add_23[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 512)          0           activation_23[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            513         lambda_3[0][0]
# ==================================================================================================
# Total params: 3,962,881
# Trainable params: 3,962,881
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 6808 samples, validate on 757 samples
# Epoch 1/300
# 6808/6808==============================] - 7s 1ms/sample - loss: 2.7096 - val_loss: 2.4265
# Epoch 2/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.5113 - val_loss: 2.2803
# Epoch 3/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.2847 - val_loss: 0.1918
# Epoch 4/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.1945 - val_loss: 0.4578
# Epoch 5/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.1564 - val_loss: 0.0198
# Epoch 6/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0980 - val_loss: 0.0596
# Epoch 7/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0847 - val_loss: 0.1329
# Epoch 8/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0580 - val_loss: 0.2508
# Epoch 9/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0554 - val_loss: 0.0514ETA: 0s - l
# Epoch 10/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0400 - val_loss: 0.1474
# Epoch 11/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0362 - val_loss: 0.1668
# Epoch 12/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0307 - val_loss: 0.1155
# Epoch 13/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0330 - val_loss: 0.0398
# Epoch 14/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0239 - val_loss: 0.0987
# Epoch 15/300
# 6808/6808==============================] - 6s 819us/sample - loss: 0.0234 - val_loss: 0.0471
# Epoch 16/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0166 - val_loss: 0.1311
# Epoch 17/300
# 6808/6808==============================] - 6s 811us/sample - loss: 0.0162 - val_loss: 0.0712
# Epoch 18/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0156 - val_loss: 0.0394
# Epoch 19/300
# 6808/6808==============================] - 6s 817us/sample - loss: 0.0163 - val_loss: 0.04830s - loss: 0.0
# Epoch 20/300
# 6808/6808==============================] - 6s 815us/sample - loss: 0.0146 - val_loss: 0.0467 ETA: 3s - l - ETA: 2s - loss: 0.014 - ETA: 2s -  - ETA: 1s - loss: 0.013 - E - ETA: 0s - loss:
# Epoch 21/300
# 6808/6808==============================] - 6s 813us/sample - loss: 0.0118 - val_loss: 0.0671
# Epoch 22/300
# 6808/6808==============================] - 6s 817us/sample - loss: 0.0119 - val_loss: 0.1057 loss: 0.012 - ETA: 2s
# Epoch 23/300
# 6808/6808==============================] - 6s 811us/sample - loss: 0.0080 - val_loss: 0.0365
# Epoch 24/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0098 - val_loss: 0.0850  - ETA: 0s - loss:  - ETA: 0s - loss
# Epoch 25/300
# 6808/6808==============================] - 6s 815us/sample - loss: 0.0097 - val_loss: 0.0624
# Epoch 26/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0083 - val_loss: 0.1039
# Epoch 27/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0081 - val_loss: 0.1445.008
# Epoch 28/300
# 6808/6808==============================] - ETA: 0s - loss: 0.0077 - 6s 820us/sample - loss: 0.0077 - val_loss: 0.1314
# Epoch 29/300
# 6808/6808==============================] - 6s 816us/sample - loss: 0.0080 - val_loss: 0.1361
# Epoch 30/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0084 - val_loss: 0.1182
# Epoch 31/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0058 - val_loss: 0.0865
# Epoch 32/300
# 6808/6808==============================] - 6s 813us/sample - loss: 0.0061 - val_loss: 0.0546
# Epoch 33/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0048 - val_loss: 0.0732
# Epoch 34/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0057 - val_loss: 0.0527
# Epoch 35/300
# 6808/6808==============================] - 6s 815us/sample - loss: 0.0048 - val_loss: 0.0440
# Epoch 36/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0038 - val_loss: 0.0498
# Epoch 37/300
# 6808/6808==============================] - 6s 815us/sample - loss: 0.0054 - val_loss: 0.0703
# Epoch 38/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0048 - val_loss: 0.0621
# Epoch 39/300
# 6808/6808==============================] - 6s 816us/sample - loss: 0.0038 - val_loss: 0.0658
# Epoch 40/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0037 - val_loss: 0.0306
# Epoch 41/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0033 - val_loss: 0.0622
# Epoch 42/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0036 - val_loss: 0.0541
# Epoch 43/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0035 - val_loss: 0.0590
# Epoch 44/300
# 6808/6808==============================] - 6s 816us/sample - loss: 0.0033 - val_loss: 0.0692
# Epoch 45/300
# 6808/6808==============================] - 6s 808us/sample - loss: 0.0038 - val_loss: 0.0461
# Epoch 46/300
# 6808/6808==============================] - 6s 808us/sample - loss: 0.0030 - val_loss: 0.0697
# Epoch 47/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0030 - val_loss: 0.0529
# Epoch 48/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0028 - val_loss: 0.0717
# Epoch 49/300
# 6808/6808==============================] - 6s 821us/sample - loss: 0.0029 - val_loss: 0.0521
# Epoch 50/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0027 - val_loss: 0.0452
# Epoch 51/300
# 6808/6808==============================] - 6s 824us/sample - loss: 0.0027 - val_loss: 0.0641
# Epoch 52/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0033 - val_loss: 0.0479
# Epoch 53/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0031 - val_loss: 0.0520
# Epoch 54/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0027 - val_loss: 0.0495
# Epoch 55/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0029 - val_loss: 0.0537
# Epoch 56/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0031 - val_loss: 0.0407 0.003
# Epoch 57/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0028 - val_loss: 0.0654 2 - ETA: 1s - l - ETA: 0s - l
# Epoch 58/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0025 - val_loss: 0.0351
# Epoch 59/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0027 - val_loss: 0.0444
# Epoch 60/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0026 - val_loss: 0.0518
# Epoch 61/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0026 - val_loss: 0.0419
# Epoch 62/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0027 - val_loss: 0.0392TA: 1s - loss: 0.002  - ETA: 0s - loss: 0.00
# Epoch 63/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0023 - val_loss: 0.0462
# Epoch 64/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0025 - val_loss: 0.0453: 2s - lo - ETA: 1s - loss - ETA: 1s - loss - ETA: 0s
# Epoch 65/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0023 - val_loss: 0.0355TA: 0s - loss: 0.0 - ETA: 0s - l
# Epoch 66/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0024 - val_loss: 0.0397
# Epoch 67/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0027 - val_loss: 0.0453
# Epoch 68/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0022 - val_loss: 0.0358
# Epoch 69/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0023 - val_loss: 0.0334
# Epoch 70/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0021 - val_loss: 0.0395
# Epoch 71/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0024 - val_loss: 0.0340
# Epoch 72/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0021 - val_loss: 0.0384
# Epoch 73/300
# 6808/6808==============================] - 6s 824us/sample - loss: 0.0019 - val_loss: 0.0349
# Epoch 74/300
# 6808/6808==============================] - 6s 824us/sample - loss: 0.0021 - val_loss: 0.0273
# Epoch 75/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0020 - val_loss: 0.0258
# Epoch 76/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0019 - val_loss: 0.0278
# Epoch 77/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0019 - val_loss: 0.0305
# Epoch 78/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0018 - val_loss: 0.0239
# Epoch 79/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0017 - val_loss: 0.0176
# Epoch 80/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0017 - val_loss: 0.0191
# Epoch 81/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0017 - val_loss: 0.0203
# Epoch 82/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0016 - val_loss: 0.0169
# Epoch 83/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0015 - val_loss: 0.0197
# Epoch 84/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0013 - val_loss: 0.0186
# Epoch 85/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0015 - val_loss: 0.0217
# Epoch 86/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0015 - val_loss: 0.0197
# Epoch 87/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0014 - val_loss: 0.0237
# Epoch 88/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0016 - val_loss: 0.0271
# Epoch 89/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0016 - val_loss: 0.0187
# Epoch 90/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0015 - val_loss: 0.02412s
# Epoch 91/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0015 - val_loss: 0.0195
# Epoch 92/300
# 6808/6808==============================] - 6s 821us/sample - loss: 0.0014 - val_loss: 0.0203
# Epoch 93/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0014 - val_loss: 0.0225
# Epoch 94/300
# 6808/6808==============================] - 6s 821us/sample - loss: 0.0017 - val_loss: 0.0213
# Epoch 95/300
# 6808/6808==============================] - 6s 819us/sample - loss: 0.0016 - val_loss: 0.0215
# Epoch 96/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0015 - val_loss: 0.0221
# Epoch 97/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0014 - val_loss: 0.0194- loss: 0 - ETA: 0
# Epoch 98/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0015 - val_loss: 0.0191
# Epoch 99/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0014 - val_loss: 0.0223
# Epoch 100/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0014 - val_loss: 0.0229
# Epoch 101/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0014 - val_loss: 0.0208s - - ETA: 0s
# Epoch 102/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0014 - val_loss: 0.0215
# Epoch 103/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0012 - val_loss: 0.0199
# Epoch 104/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0014 - val_loss: 0.0166 0s - loss
# Epoch 105/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0014 - val_loss: 0.0181- ETA: 1s  - ETA: 0s - loss:
# Epoch 106/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0014 - val_loss: 0.0138- loss: 0. - ETA: 1s - - ETA: 0s - lo
# Epoch 107/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0014 - val_loss: 0.0181loss: 0.00 - ETA: 0s - loss: 0.00 - ETA: 0s - loss:
# Epoch 108/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0014 - val_loss: 0.0201loss: 0 - ETA: 0s - loss: 0 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.00
# Epoch 109/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0015 - val_loss: 0.0199
# Epoch 110/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0013 - val_loss: 0.0178s: 9.6985e-0 - ETA: 1s - - ETA: 0s - los
# Epoch 111/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0012 - val_loss: 0.0158
# Epoch 112/300
# 6808/6808==============================] - 6s 810us/sample - loss: 0.0013 - val_loss: 0.0176
# Epoch 113/300
# 6808/6808==============================] - 5s 803us/sample - loss: 0.0013 - val_loss: 0.0154
# Epoch 114/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0014 - val_loss: 0.0196 -
# Epoch 115/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0012 - val_loss: 0.0149
# Epoch 116/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0012 - val_loss: 0.0154
# Epoch 117/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0013 - val_loss: 0.0123
# Epoch 118/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0013 - val_loss: 0.0157
# Epoch 119/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0013 - val_loss: 0.0139
# Epoch 120/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0012 - val_loss: 0.0139oss: 0.0
# Epoch 121/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0012 - val_loss: 0.0149
# Epoch 122/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0012 - val_loss: 0.0143
# Epoch 123/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0011 - val_loss: 0.0172
# Epoch 124/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0012 - val_loss: 0.0120
# Epoch 125/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0012 - val_loss: 0.0155
# Epoch 126/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0011 - val_loss: 0.0134
# Epoch 127/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0011 - val_loss: 0.0152
# Epoch 128/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0011 - val_loss: 0.0141
# Epoch 129/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0011 - val_loss: 0.0153
# Epoch 130/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0011 - val_loss: 0.0126
# Epoch 131/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0010 - val_loss: 0.0126
# Epoch 132/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0011 - val_loss: 0.0138
# Epoch 133/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0010 - val_loss: 0.0130
# Epoch 134/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0011 - val_loss: 0.0140
# Epoch 135/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0011 - val_loss: 0.0127
# Epoch 136/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0010 - val_loss: 0.0151 - loss:  - ETA: 0s -
# Epoch 137/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0010 - val_loss: 0.0114
# Epoch 138/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0010 - val_loss: 0.0089
# Epoch 139/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0010 - val_loss: 0.0103 - ETA: 0s -
# Epoch 140/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0011 - val_loss: 0.0102 - loss: 4.7358 - ETA: 2s - loss -  - ETA: 0s - loss: 9.
# Epoch 141/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0010 - val_loss: 0.0120
# Epoch 142/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0010 - val_loss: 0.0127  - ETA: 1s - loss: 7.8850e-0 - ETA: 1s - loss: 7.967 - ETA: 0s - l
# Epoch 143/300
# 6808/6808==============================] - 6s 829us/sample - loss: 9.6704e-04 - val_loss: 0.0093
# Epoch 144/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0011 - val_loss: 0.0079
# Epoch 145/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0010 - val_loss: 0.0107
# Epoch 146/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0010 - val_loss: 0.0125
# Epoch 147/300
# 6808/6808==============================] - 6s 825us/sample - loss: 9.8137e-04 - val_loss: 0.0079
# Epoch 148/300
# 6808/6808==============================] - 6s 827us/sample - loss: 9.7975e-04 - val_loss: 0.0097
# Epoch 149/300
# 6808/6808==============================] - 6s 825us/sample - loss: 9.5112e-04 - val_loss: 0.0086
# Epoch 150/300
# 6808/6808==============================] - 6s 827us/sample - loss: 9.5872e-04 - val_loss: 0.0107
# Epoch 151/300
# 6808/6808==============================] - 6s 825us/sample - loss: 9.2623e-04 - val_loss: 0.0087
# Epoch 152/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0010 - val_loss: 0.0104
# Epoch 153/300
# 6808/6808==============================] - 6s 823us/sample - loss: 9.7965e-04 - val_loss: 0.0088
# Epoch 154/300
# 6808/6808==============================] - 6s 823us/sample - loss: 9.2220e-04 - val_loss: 0.0100
# Epoch 155/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.
300
# 6808/6808==============================] - 6s 825us/sample - loss: 7.3072e-04 - val_loss: 0.0073
# Epoch 291/300
# 6808/6808==============================] - 6s 822us/sample - loss: 6.9197e-04 - val_loss: 0.0064
# Epoch 292/300
# 6808/6808==============================] - 6s 818us/sample - loss: 7.0809e-04 - val_loss: 0.0070
# Epoch 293/300
# 6808/6808==============================] - 6s 822us/sample - loss: 6.8806e-04 - val_loss: 0.0069: 0s - loss: 5 - ETA: 0s - loss: 6.07
# Epoch 294/300
# 6808/6808==============================] - 6s 823us/sample - loss: 6.8779e-04 - val_loss: 0.0067
# Epoch 295/300
# 6808/6808==============================] - 6s 823us/sample - loss: 6.7743e-04 - val_loss: 0.0058
# Epoch 296/300
# 6808/6808==============================] - 6s 822us/sample - loss: 6.9711e-04 - val_loss: 0.0052
# Epoch 297/300
# 6808/6808==============================] - 6s 825us/sample - loss: 7.0704e-04 - val_loss: 0.0062 loss: 6.6900e
# Epoch 298/300
# 6808/6808==============================] - 6s 823us/sample - loss: 6.5520e-04 - val_loss: 0.0053A:  - ETA: 1s - loss: 4.358 - ETA: 1s - loss:  - ETA: 0s - loss: 5.7345e- - ETA: 0s - loss: 5.
# Epoch 299/300
# 6808/6808==============================] - 6s 825us/sample - loss: 6.5034e-04 - val_loss: 0.0063A: 0s - loss: 5
# Epoch 300/300
# 6808/6808==============================] - 6s 823us/sample - loss: 6.9084e-04 - val_loss: 0.0071

# %%
plot_model_architecture(model=model, file_name=file_name)
y_pred = predict_image(history_model=history_model,X_tst_t=X_tst_t,input_tensor=input_tensor,
                  
                  predict_imagepath=predict_imagepath, file_name=file_name)
loss_image(history_model=history_model, loss_imagepath=loss_imagepath, file_name=file_name)
save_csv(y_pred=y_pred,X_train=X_train,X_test=X_test,Target_DirPath=Target_DirPath,
             file_name=file_name,test_date=test_date)
save_train_csv(file_name=file_name)
# Out:
# y_pred.shape: (1756, 1)
# y_test_rsquare.shape: (1756,)
# R-Squared: 0.914756
# The Adjusted R2 score on the Test set is:	0.912
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# # custom r2 score

# %%
for iter_number in range(9,10):
    iter_number = str(iter_number)
    file_name='NYA_de5_try2_clf5_pe10_tcn'+iter_number
    print(file_name+":")
    custom_r2_score(file_name)
# Out:
# NYA_de5_clf5_pe10_tcn9:
# (1756,)
# The Adjusted R2 score on the Test set is:	0.912
# The Custom  sign score on the Test set is:	0.510
# The Custom  R2 score on the Test set is:	0.711

# %%
#tcn9
file_name='NYA_de5_try2_clf5_pe100_tcn9'
penalty=100

# %%
X_tr_t = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_tst_t = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])


input_tensor= Input(shape=(1,X_train.shape[1],))
output = TCN(nb_filters=512, kernel_size=2, nb_stacks=1, dilations=[1, 2, 4, 8, 16], \
        activation='selu', padding='causal', use_skip_connections=True,\
        dropout_rate=0.3, return_sequences=False, name='tcn')(input_tensor)  # The TCN layers are here.

output_tensor = Dense(1)(output)
model = Model([input_tensor], output_tensor)
model.compile(optimizer=Adam(lr=0.0001, clipnorm=1, clipvalue=0.5), loss=tf_stock_loss_8)
model.summary()
early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
history_model = model.fit(x=[X_tr_t], y=y_train, epochs=300, 
                                    batch_size=16, verbose=1,
                                    validation_split= val_split_ratio, callbacks=[CSV(losspath=losspath, file_name=file_name)],
                                    shuffle=False)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 1, 48)]      0
# __________________________________________________________________________________________________
# tcn_initial_conv (Conv1D)       (None, 1, 512)       25088       input_5[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_1_tanh_s0 (Co (None, 1, 512)       524800      tcn_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_1_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_1_s0_0.30 (None, 1, 512)       0           activation_24[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_1_s0_0.3000
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 1, 512)       0           tcn_initial_conv[0][0]
#                                                                  conv1d_20[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_2_tanh_s0 (Co (None, 1, 512)       524800      add_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_2_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_2_s0_0.30 (None, 1, 512)       0           activation_25[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_2_s0_0.3000
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 1, 512)       0           add_24[0][0]
#                                                                  conv1d_21[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_4_tanh_s0 (Co (None, 1, 512)       524800      add_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_4_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_4_s0_0.30 (None, 1, 512)       0           activation_26[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_4_s0_0.3000
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 1, 512)       0           add_25[0][0]
#                                                                  conv1d_22[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_8_tanh_s0 (Co (None, 1, 512)       524800      add_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_8_tanh_s0[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_8_s0_0.30 (None, 1, 512)       0           activation_27[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_8_s0_0.3000
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 1, 512)       0           add_26[0][0]
#                                                                  conv1d_23[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_16_tanh_s0 (C (None, 1, 512)       524800      add_27[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 1, 512)       0           tcn_d_causal_conv_16_tanh_s0[0][0
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_16_s0_0.3 (None, 1, 512)       0           activation_28[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 1, 512)       262656      tcn_spatial_dropout1d_16_s0_0.300
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 1, 512)       0           conv1d_20[0][0]
#                                                                  conv1d_21[0][0]
#                                                                  conv1d_22[0][0]
#                                                                  conv1d_23[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 1, 512)       0           add_29[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 512)          0           activation_29[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            513         lambda_4[0][0]
# ==================================================================================================
# Total params: 3,962,881
# Trainable params: 3,962,881
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 6808 samples, validate on 757 samples
# Epoch 1/300
# 6808/6808==============================] - 8s 1ms/sample - loss: 23.6485 - val_loss: 0.1253
# Epoch 2/300
# 6808/6808==============================] - 6s 832us/sample - loss: 4.5778 - val_loss: 11.8732
# Epoch 3/300
# 6808/6808==============================] - 6s 831us/sample - loss: 2.3406 - val_loss: 4.3382
# Epoch 4/300
# 6808/6808==============================] - 6s 834us/sample - loss: 1.6652 - val_loss: 0.2703
# Epoch 5/300
# 6808/6808==============================] - 6s 829us/sample - loss: 1.1281 - val_loss: 1.4909
# Epoch 6/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.9459 - val_loss: 1.3342
# Epoch 7/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.6428 - val_loss: 3.8140
# Epoch 8/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.5613 - val_loss: 1.2108
# Epoch 9/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.4445 - val_loss: 1.1823
# Epoch 10/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.3679 - val_loss: 0.0506
# Epoch 11/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.3172 - val_loss: 0.1579
# Epoch 12/300
# 6808/6808==============================] - 6s 815us/sample - loss: 0.2854 - val_loss: 0.7843
# Epoch 13/300
# 6808/6808==============================] - 6s 815us/sample - loss: 0.2476 - val_loss: 1.1286
# Epoch 14/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.2225 - val_loss: 1.2604
# Epoch 15/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.1787 - val_loss: 0.0382
# Epoch 16/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.1835 - val_loss: 0.2708
# Epoch 17/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.1658 - val_loss: 0.8355
# Epoch 18/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.1422 - val_loss: 1.3700TA: 0s - los
# Epoch 19/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.1160 - val_loss: 0.7552
# Epoch 20/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.1089 - val_loss: 1.3616 - loss: 0.1
# Epoch 21/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0814 - val_loss: 0.7688
# Epoch 22/300
# 6808/6808==============================] - ETA: 0s - loss: 0.087 - 6s 830us/sample - loss: 0.0873 - val_loss: 0.3741
# Epoch 23/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0709 - val_loss: 1.2495
# Epoch 24/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0798 - val_loss: 0.7730
# Epoch 25/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0682 - val_loss: 0.5958
# Epoch 26/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0613 - val_loss: 0.5835
# Epoch 27/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0575 - val_loss: 0.5842
# Epoch 28/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0529 - val_loss: 0.6960- loss
# Epoch 29/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0555 - val_loss: 1.0127oss: 0.04 - ETA: 2s - loss: 0 - ETA:
# Epoch 30/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0730 - val_loss: 0.4885
# Epoch 31/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0499 - val_loss: 0.2247
# Epoch 32/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0470 - val_loss: 0.8855
# Epoch 33/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0517 - val_loss: 0.5870
# Epoch 34/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0489 - val_loss: 0.2821
# Epoch 35/300
# 6808/6808==============================] - 6s 824us/sample - loss: 0.0578 - val_loss: 0.4493
# Epoch 36/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0390 - val_loss: 0.3699
# Epoch 37/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0332 - val_loss: 0.3080
# Epoch 38/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0316 - val_loss: 0.5069
# Epoch 39/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0313 - val_loss: 0.4566
# Epoch 40/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0354 - val_loss: 0.6929
# Epoch 41/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0408 - val_loss: 0.4397
# Epoch 42/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0321 - val_loss: 0.4348
# Epoch 43/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0316 - val_loss: 0.5434
# Epoch 44/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0367 - val_loss: 0.4283
# Epoch 45/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0310 - val_loss: 0.4215
# Epoch 46/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0277 - val_loss: 0.4713
# Epoch 47/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0274 - val_loss: 0.3441
# Epoch 48/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0294 - val_loss: 0.4143
# Epoch 49/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0244 - val_loss: 0.3963
# Epoch 50/300
# 6808/6808==============================] - 6s 824us/sample - loss: 0.0285 - val_loss: 0.4022
# Epoch 51/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0245 - val_loss: 0.4537
# Epoch 52/300
# 6808/6808==============================] - ETA: 0s - loss: 0.0281- ETA:  - 6s 825us/sample - loss: 0.0282 - val_loss: 0.2845
# Epoch 53/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0237 - val_loss: 0.3109
# Epoch 54/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0230 - val_loss: 0.2263
# Epoch 55/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0239 - val_loss: 0.2846
# Epoch 56/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0240 - val_loss: 0.2510
# Epoch 57/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0223 - val_loss: 0.1912
# Epoch 58/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0222 - val_loss: 0.2303
# Epoch 59/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0225 - val_loss: 0.1865
# Epoch 60/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0201 - val_loss: 0.2307
# Epoch 61/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0186 - val_loss: 0.2617
# Epoch 62/300
# 6808/6808==============================] - 6s 833us/sample - loss: 0.0208 - val_loss: 0.2677
# Epoch 63/300
# 6808/6808==============================] - 6s 834us/sample - loss: 0.0190 - val_loss: 0.2523
# Epoch 64/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0191 - val_loss: 0.3201
# Epoch 65/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0174 - val_loss: 0.24681 - ETA: 0s - loss:
# Epoch 66/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0185 - val_loss: 0.2375
# Epoch 67/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0177 - val_loss: 0.18051s - loss:
# Epoch 68/300
# 6808/6808==============================] - 6s 834us/sample - loss: 0.0191 - val_loss: 0.2739
# Epoch 69/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0163 - val_loss: 0.2276TA: 0s - loss: 0
# Epoch 70/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0178 - val_loss: 0.2051
# Epoch 71/300
# 6808/6808==============================] - 6s 833us/sample - loss: 0.0164 - val_loss: 0.2292
# Epoch 72/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0160 - val_loss: 0.2454
# Epoch 73/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0170 - val_loss: 0.3112
# Epoch 74/300
# 6808/6808==============================] - 6s 833us/sample - loss: 0.0187 - val_loss: 0.2341
# Epoch 75/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0160 - val_loss: 0.2133
# Epoch 76/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0183 - val_loss: 0.2411
# Epoch 77/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0157 - val_loss: 0.2111
# Epoch 78/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0164 - val_loss: 0.2702
# Epoch 79/300
# 6808/6808==============================] - 6s 816us/sample - loss: 0.0173 - val_loss: 0.2189
# Epoch 80/300
# 6808/6808==============================] - 6s 817us/sample - loss: 0.0179 - val_loss: 0.2362
# Epoch 81/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0180 - val_loss: 0.1932
# Epoch 82/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0162 - val_loss: 0.1770
# Epoch 83/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0171 - val_loss: 0.1984
# Epoch 84/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0166 - val_loss: 0.1970
# Epoch 85/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0143 - val_loss: 0.1536
# Epoch 86/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0147 - val_loss: 0.1499
# Epoch 87/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0146 - val_loss: 0.1686os - ETA: 2s - los - ETA: 1s - - ETA: 0s
# Epoch 88/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0144 - val_loss: 0.2023
# Epoch 89/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0129 - val_loss: 0.1970
# Epoch 90/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0154 - val_loss: 0.2031
# Epoch 91/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0134 - val_loss: 0.1786: 0s - loss:
# Epoch 92/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0129 - val_loss: 0.1507TA: 1s - loss: 0 - ETA: 1s -  - ETA: 0s
# Epoch 93/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0126 - val_loss: 0.1323: 0s - loss:
# Epoch 94/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0136 - val_loss: 0.1619
# Epoch 95/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0117 - val_loss: 0.2124
# Epoch 96/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0130 - val_loss: 0.1687
# Epoch 97/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0131 - val_loss: 0.1553
# Epoch 98/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0133 - val_loss: 0.1346
# Epoch 99/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0140 - val_loss: 0.1618
# Epoch 100/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0134 - val_loss: 0.1535
# Epoch 101/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0111 - val_loss: 0.1397s - loss:
# Epoch 102/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0105 - val_loss: 0.1279
# Epoch 103/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0120 - val_loss: 0.1458
# Epoch 104/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0115 - val_loss: 0.1343TA: 0s - l
# Epoch 105/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0107 - val_loss: 0.1307
# Epoch 106/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0106 - val_loss: 0.1269
# Epoch 107/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0107 - val_loss: 0.1425
# Epoch 108/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0101 - val_loss: 0.1000
# Epoch 109/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0110 - val_loss: 0.1325
# Epoch 110/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0103 - val_loss: 0.1220
# Epoch 111/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0112 - val_loss: 0.1209
# Epoch 112/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0110 - val_loss: 0.1205
# Epoch 113/300
# 6808/6808==============================] - 6s 824us/sample - loss: 0.0101 - val_loss: 0.1549
# Epoch 114/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0106 - val_loss: 0.1345
# Epoch 115/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0109 - val_loss: 0.1243
# Epoch 116/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0110 - val_loss: 0.1213
# Epoch 117/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0121 - val_loss: 0.1192
# Epoch 118/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0100 - val_loss: 0.1347
# Epoch 119/300
# 6808/6808==============================] - 6s 824us/sample - loss: 0.0107 - val_loss: 0.1715 - loss: 0.00 - ETA: 2s  -  - ETA: 0s - loss: 0
# Epoch 120/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0114 - val_loss: 0.1130
# Epoch 121/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0108 - val_loss: 0.0924
# Epoch 122/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0102 - val_loss: 0.1131
# Epoch 123/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0118 - val_loss: 0.1137 2s -
# Epoch 124/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0103 - val_loss: 0.1023
# Epoch 125/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0108 - val_loss: 0.1284
# Epoch 126/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0104 - val_loss: 0.1157
# Epoch 127/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0104 - val_loss: 0.1035
# Epoch 128/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0106 - val_loss: 0.0984
# Epoch 129/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0101 - val_loss: 0.1076
# Epoch 130/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0106 - val_loss: 0.1082
# Epoch 131/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0105 - val_loss: 0.1123
# Epoch 132/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0126 - val_loss: 0.0920
# Epoch 133/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0114 - val_loss: 0.1228
# Epoch 134/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0107 - val_loss: 0.0848
# Epoch 135/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0106 - val_loss: 0.1013
# Epoch 136/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0103 - val_loss: 0.1194 - loss: 0 - ETA: 1s -  - ETA: 0s
# Epoch 137/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0103 - val_loss: 0.0999
# Epoch 138/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0098 - val_loss: 0.1153
# Epoch 139/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0111 - val_loss: 0.13120s - loss:
# Epoch 140/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0108 - val_loss: 0.0943
# Epoch 141/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0101 - val_loss: 0.0901
# Epoch 142/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0101 - val_loss: 0.1076
# Epoch 143/300
# 6808/6808==============================] - 6s 833us/sample - loss: 0.0109 - val_loss: 0.0941 - ET
# Epoch 144/300
# 6808/6808==============================] - ETA: 0s - loss: 0.010 - 6s 830us/sample - loss: 0.0101 - val_loss: 0.0960
# Epoch 145/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0103 - val_loss: 0.0903
# Epoch 146/300
# 6808/6808==============================] - 6s 814us/sample - loss: 0.0104 - val_loss: 0.0836
# Epoch 147/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0104 - val_loss: 0.0987
# Epoch 148/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0103 - val_loss: 0.1007
# Epoch 149/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0092 - val_loss: 0.0695 2s -  - E - ETA: 0s - loss: 0.
# Epoch 150/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0097 - val_loss: 0.0975TA
# Epoch 151/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0102 - val_loss: 0.0738
# Epoch 152/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0101 - val_loss: 0.0910
# Epoch 153/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0090 - val_loss: 0.0904
# Epoch 154/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0093 - val_loss: 0.0932
# Epoch 155/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0093 - val_loss: 0.0832
# Epoch 156/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0095 - val_loss: 0.1031
# Epoch 157/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0078 - val_loss: 0.1057
# Epoch 158/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0088 - val_loss: 0.0873s - loss: 0.00 - ETA: 2s - loss: 0 - ETA:
# Epoch 159/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0091 - val_loss: 0.0947
# Epoch 160/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0088 - val_loss: 0.0857 - loss: 0 - ETA: 1s - - ETA: 0s - loss:
# Epoch 161/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0089 - val_loss: 0.1017
# Epoch 162/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0086 - val_loss: 0.0815
# Epoch 163/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0081 - val_loss: 0.0780
# Epoch 164/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0081 - val_loss: 0.0776
# Epoch 165/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0084 - val_loss: 0.0596
# Epoch 166/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0083 - val_loss: 0.0560
# Epoch 167/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0093 - val_loss: 0.0695A: 2s - loss: 0 - ETA: 2s -  - ETA: 1s - los -
# Epoch 168/300
# 6808/6808==============================] - 6s 824us/sample - loss: 0.0082 - val_loss: 0.0646
# Epoch 169/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0092 - val_loss: 0.0790
# Epoch 170/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0090 - val_loss: 0.0595- ETA: 2s - loss: 0.004 - ETA: 2s -  - ETA: 2s  -
# Epoch 171/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0088 - val_loss: 0.0826
# Epoch 172/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0090 - val_loss: 0.0653
# Epoch 173/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0084 - val_loss: 0.08920s -  - ETA: 0s - loss: 0.
# Epoch 174/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0079 - val_loss: 0.0561
# Epoch 175/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0084 - val_loss: 0.0754
# Epoch 176/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0080 - val_loss: 0.0736
# Epoch 177/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0082 - val_loss: 0.0807
# Epoch 178/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0080 - val_loss: 0.0760
# Epoch 179/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0080 - val_loss: 0.0774s - loss:
# Epoch 180/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0077 - val_loss: 0.0888
# Epoch 181/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0089 - val_loss: 0.0545
# Epoch 182/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0083 - val_loss: 0.0750- loss: 0.00 - ETA: 0s - loss: 0.00 - ETA: 0s - loss: 0.00 - ETA: 0s - loss
# Epoch 183/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0092 - val_loss: 0.0670
# Epoch 184/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0081 - val_loss: 0.0643 4s - loss:  -
# Epoch 185/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0080 - val_loss: 0.0827
# Epoch 186/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0089 - val_loss: 0.0872TA: 0s - l
# Epoch 187/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0084 - val_loss: 0.05842 - ETA: 0s - loss: 0.00 - ETA: 0s - lo
# Epoch 188/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0073 - val_loss: 0.0777 - ETA: 1s - loss:  -
# Epoch 189/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0088 - val_loss: 0.0697
# Epoch 190/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0082 - val_loss: 0.0791s - loss: 0.008
# Epoch 191/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0082 - val_loss: 0.0652 1s - loss: 0.00
# Epoch 192/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0083 - val_loss: 0.0715
# Epoch 193/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0079 - val_loss: 0.0554ss: 0.00
# Epoch 194/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0086 - val_loss: 0.0675
# Epoch 195/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0083 - val_loss: 0.0725
# Epoch 196/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0090 - val_loss: 0.0675A: 0s - loss:  - ETA: 0s - loss: 0.
# Epoch 197/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0084 - val_loss: 0.0791
# Epoch 198/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0083 - val_loss: 0.0546
# Epoch 199/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0083 - val_loss: 0.0680
# Epoch 200/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0081 - val_loss: 0.0950
# Epoch 201/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0085 - val_loss: 0.0701
# Epoch 202/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0085 - val_loss: 0.0830
# Epoch 203/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0080 - val_loss: 0.0664
# Epoch 204/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0081 - val_loss: 0.0709
# Epoch 205/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0080 - val_loss: 0.0733s - loss: 0. - ETA: 1s - ETA: 0s - los - ETA: 0s - loss:
# Epoch 206/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0077 - val_loss: 0.0576
# Epoch 207/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0088 - val_loss: 0.0652
# Epoch 208/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0080 - val_loss: 0.0587
# Epoch 209/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0083 - val_loss: 0.0546
# Epoch 210/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0096 - val_loss: 0.0883A: 0s - loss:
# Epoch 211/300
# 6808/6808==============================] - 6s 834us/sample - loss: 0.0081 - val_loss: 0.0631A: 0s - loss: 0
# Epoch 212/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0078 - val_loss: 0.0867
# Epoch 213/300
# 6808/6808==============================] - ETA: 0s - loss: 0.007 - 6s 813us/sample - loss: 0.0078 - val_loss: 0.0938
# Epoch 214/300
# 6808/6808==============================] - 6s 818us/sample - loss: 0.0076 - val_loss: 0.0746
# Epoch 215/300
# 6808/6808==============================] - 6s 834us/sample - loss: 0.0082 - val_loss: 0.0859
# Epoch 216/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0089 - val_loss: 0.0767
# Epoch 217/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0085 - val_loss: 0.0799
# Epoch 218/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0072 - val_loss: 0.0741
# Epoch 219/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0077 - val_loss: 0.0664
# Epoch 220/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0082 - val_loss: 0.0970TA: 0s - los
# Epoch 221/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0082 - val_loss: 0.0818
# Epoch 222/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0097 - val_loss: 0.0923
# Epoch 223/300
# 6808/6808==============================] - 6s 835us/sample - loss: 0.0081 - val_loss: 0.1144
# Epoch 224/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0079 - val_loss: 0.0662
# Epoch 225/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0080 - val_loss: 0.0689
# Epoch 226/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0077 - val_loss: 0.0867
# Epoch 227/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0084 - val_loss: 0.0827
# Epoch 228/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0082 - val_loss: 0.0800 - loss: 0.
# Epoch 229/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0096 - val_loss: 0.0884 - loss: 0.0
# Epoch 230/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0083 - val_loss: 0.0949
# Epoch 231/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0081 - val_loss: 0.0946
# Epoch 232/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0087 - val_loss: 0.0823
# Epoch 233/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0088 - val_loss: 0.0799
# Epoch 234/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0081 - val_loss: 0.0804
# Epoch 235/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0084 - val_loss: 0.0861
# Epoch 236/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0085 - val_loss: 0.0678
# Epoch 237/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0085 - val_loss: 0.0682
# Epoch 238/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0096 - val_loss: 0.0699
# Epoch 239/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0083 - val_loss: 0.0646
# Epoch 240/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0081 - val_loss: 0.0705
# Epoch 241/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0085 - val_loss: 0.0710 ETA: 1s - loss - ETA: 0s -  - ETA: 0s - loss: 0.
# Epoch 242/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0089 - val_loss: 0.0664
# Epoch 243/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0081 - val_loss: 0.0716
# Epoch 244/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0083 - val_loss: 0.0697 0s - loss: 0.0 - ETA: 0s - loss:  - ETA: 0s - loss: 0
# Epoch 245/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0087 - val_loss: 0.0921ss:  - ETA: 0s - loss
# Epoch 246/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0080 - val_loss: 0.0718
# Epoch 247/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0082 - val_loss: 0.0646
# Epoch 248/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0081 - val_loss: 0.0588
# Epoch 249/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0079 - val_loss: 0.0656
# Epoch 250/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0091 - val_loss: 0.0836
# Epoch 251/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0077 - val_loss: 0.0700
# Epoch 252/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0083 - val_loss: 0.0768
# Epoch 253/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0084 - val_loss: 0.0769
# Epoch 254/300
# 6808/6808==============================] - 6s 823us/sample - loss: 0.0084 - val_loss: 0.0756
# Epoch 255/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0083 - val_loss: 0.0712
# Epoch 256/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0084 - val_loss: 0.0649
# Epoch 257/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0079 - val_loss: 0.0835
# Epoch 258/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0090 - val_loss: 0.0775
# Epoch 259/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0089 - val_loss: 0.0684
# Epoch 260/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0083 - val_loss: 0.0722
# Epoch 261/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0083 - val_loss: 0.0787
# Epoch 262/300
# 6808/6808==============================] - 6s 822us/sample - loss: 0.0091 - val_loss: 0.0894
# Epoch 263/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0077 - val_loss: 0.0882
# Epoch 264/300
# 6808/6808==============================] - 6s 826us/sample - loss: 0.0084 - val_loss: 0.0613
# Epoch 265/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0079 - val_loss: 0.0923
# Epoch 266/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0080 - val_loss: 0.0838
# Epoch 267/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0085 - val_loss: 0.0733
# Epoch 268/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0086 - val_loss: 0.0938
# Epoch 269/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0086 - val_loss: 0.0722
# Epoch 270/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0085 - val_loss: 0.0695
# Epoch 271/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0095 - val_loss: 0.0705
# Epoch 272/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0083 - val_loss: 0.0637
# Epoch 273/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0084 - val_loss: 0.0685
# Epoch 274/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0079 - val_loss: 0.0685 - ETA: 0s - loss: 0.0 - ETA: 0s - loss: 0.
# Epoch 275/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0088 - val_loss: 0.0812
# Epoch 276/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0077 - val_loss: 0.0867
# Epoch 277/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0092 - val_loss: 0.0817A: 0s - loss: 0.009
# Epoch 278/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0079 - val_loss: 0.0964
# Epoch 279/300
# 6808/6808==============================] - 6s 820us/sample - loss: 0.0088 - val_loss: 0.0866
# Epoch 280/300
# 6808/6808==============================] - 6s 814us/sample - loss: 0.0081 - val_loss: 0.0741
# Epoch 281/300
# 6808/6808==============================] - 6s 825us/sample - loss: 0.0086 - val_loss: 0.0814
# Epoch 282/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0083 - val_loss: 0.0790
# Epoch 283/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0075 - val_loss: 0.0787
# Epoch 284/300
# 6808/6808==============================] - 6s 834us/sample - loss: 0.0087 - val_loss: 0.0917
# Epoch 285/300
# 6808/6808==============================] - 6s 833us/sample - loss: 0.0076 - val_loss: 0.0731
# Epoch 286/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0082 - val_loss: 0.0783
# Epoch 287/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0088 - val_loss: 0.1136
# Epoch 288/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0089 - val_loss: 0.0770
# Epoch 289/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0076 - val_loss: 0.0895
# Epoch 290/300
# 6808/6808==============================] - 6s 832us/sample - loss: 0.0085 - val_loss: 0.1222
# Epoch 291/300
# 6808/6808==============================] - 6s 827us/sample - loss: 0.0090 - val_loss: 0.1587
# Epoch 292/300
# 6808/6808==============================] - 6s 831us/sample - loss: 0.0086 - val_loss: 0.1030
# Epoch 293/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0100 - val_loss: 0.0991
# Epoch 294/300
# 6808/6808==============================] - 6s 833us/sample - loss: 0.0081 - val_loss: 0.0845
# Epoch 295/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0089 - val_loss: 0.1149
# Epoch 296/300
# 6808/6808==============================] - 6s 834us/sample - loss: 0.0085 - val_loss: 0.0754
# Epoch 297/300
# 6808/6808==============================] - 6s 834us/sample - loss: 0.0088 - val_loss: 0.1139
# Epoch 298/300
# 6808/6808==============================] - 6s 830us/sample - loss: 0.0093 - val_loss: 0.1100
# Epoch 299/300
# 6808/6808==============================] - 6s 829us/sample - loss: 0.0085 - val_loss: 0.1178
# Epoch 300/300
# 6808/6808==============================] - 6s 828us/sample - loss: 0.0083 - val_loss: 0.1204

# %%
plot_model_architecture(model=model, file_name=file_name)
y_pred = predict_image(history_model=history_model,X_tst_t=X_tst_t,input_tensor=input_tensor,
                  
                  predict_imagepath=predict_imagepath, file_name=file_name)
loss_image(history_model=history_model, loss_imagepath=loss_imagepath, file_name=file_name)
save_csv(y_pred=y_pred,X_train=X_train,X_test=X_test,Target_DirPath=Target_DirPath,
             file_name=file_name,test_date=test_date)
save_train_csv(file_name=file_name)
# Out:
# y_pred.shape: (1756, 1)
# y_test_rsquare.shape: (1756,)
# R-Squared: 0.047918
# The Adjusted R2 score on the Test set is:	0.021
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# # custom r2 score

# %%
for iter_number in range(9,10):
    iter_number = str(iter_number)
    file_name='NYA_de5_try2_clf5_pe100_tcn'+iter_number
    print(file_name+":")
    custom_r2_score(file_name)
# Out:
# NYA_de5_clf5_pe100_tcn9:
# (1756,)
# The Adjusted R2 score on the Test set is:	0.021
# The Custom  sign score on the Test set is:	0.504
# The Custom  R2 score on the Test set is:	0.262
